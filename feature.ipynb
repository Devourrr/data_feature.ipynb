# %%
import requests

url = 'http://apis.data.go.kr/B552061/lgStat/getRestLgStat'

params = {
    "ServiceKey" : 'HCnD0rtW2xL5JgkUNzOEFPuVQO9FxnqdTxFgkAkNYh2eacEW62WkpsWVn7W+UoQNKJXa1HIc8IR9t6ZkI4wzIA=='
    , 'searchYearCd': 2019
    , 'siDo': 1100
    , 'guGun': 1116
    , 'type': 'json'
    , 'numOfRows': 13
    , 'pageNo': 1
}

res = requests.get(url, params = params)
print(res.status_code)
print(res.text)
# Out:
# 200
# {"resultCode":"00","resultMsg":"NORMAL_CODE","items":{"item":[{"std_year":"2019","sido_sgg_nm":"서울특별시 강남구","acc_cl_nm":"전체사고","acc_cnt":"3722","acc_cnt_cmrt":"1.62","dth_dnv_cnt":"14","dth_dnv_cnt_cmrt":"0.42","ftlt_rate":"0.38","injpsn_cnt":"5182","injpsn_cnt_cmrt":"1.52","tot_acc_cnt":"229600","tot_dth_dnv_cnt":"3349","tot_injpsn_cnt":"341712","pop_100k":"675.81","car_10k":"147.41","cnt_027_01":"13","cnt_027_02":"76","cnt_027_03":"330","cnt_027_04":"515","cnt_027_05":"2150","cnt_027_06":"154","cnt_027_07":"125","cnt_027_99":"359","cnt_014_01":"825","cnt_014_02":"2832","cnt_014_03":"65","cnt_014_04":"0"},{"std_year":"2019","sido_sgg_nm":"서울특별시 강남구","acc_cl_nm":"어린이사고","acc_cnt":"107","acc_cnt_cmrt":"0.97","dth_dnv_cnt":"0","dth_dnv_cnt_cmrt":"0.00","ftlt_rate":"0.00","injpsn_cnt":"126","injpsn_cnt_cmrt":"0.89","tot_acc_cnt":"11054","tot_dth_dnv_cnt":"28","tot_injpsn_cnt":"14115"},{"std_year":"2019","sido_sgg_nm":"서울특별시 강남구","acc_cl_nm":"고령자사고","acc_cnt":"352","acc_cnt_cmrt":"0.87","dth_dnv_cnt":"6","dth_dnv_cnt_cmrt":"0.39","ftlt_rate":"1.70","injpsn_cnt":"366","injpsn_cnt_cmrt":"0.82","tot_acc_cnt":"40645","tot_dth_dnv_cnt":"1523","tot_injpsn_cnt":"44390"},{"std_year":"2019","sido_sgg_nm":"서울특별시 강남구","acc_cl_nm":"보행자사고","acc_cnt":"839","acc_cnt_cmrt":"1.80","dth_dnv_cnt":"8","dth_dnv_cnt_cmrt":"0.61","ftlt_rate":"0.95","injpsn_cnt":"863","injpsn_cnt_cmrt":"1.83","tot_acc_cnt":"46682","tot_dth_dnv_cnt":"1302","tot_injpsn_cnt":"47200"},{"std_year":"2019","sido_sgg_nm":"서울특별시 강남구","acc_cl_nm":"자전거사고","acc_cnt":"60","acc_cnt_cmrt":"1.07","dth_dnv_cnt":"0","dth_dnv_cnt_cmrt":"0.00","ftlt_rate":"0.00","injpsn_cnt":"70","injpsn_cnt_cmrt":"1.16","tot_acc_cnt":"5633","tot_dth_dnv_cnt":"79","tot_injpsn_cnt":"6020"},{"std_year":"2019","sido_sgg_nm":"서울특별시 강남구","acc_cl_nm":"야간사고","acc_cnt":"1688","acc_cnt_cmrt":"1.85","dth_dnv_cnt":"10","dth_dnv_cnt_cmrt":"0.63","ftlt_rate":"0.59","injpsn_cnt":"2421","injpsn_cnt_cmrt":"1.80","tot_acc_cnt":"91067","tot_dth_dnv_cnt":"1599","tot_injpsn_cnt":"134686"},{"std_year":"2019","sido_sgg_nm":"서울특별시 강남구","acc_cl_nm":"어린이보행사고","acc_cnt":"44","acc_cnt_cmrt":"1.14","dth_dnv_cnt":"0","dth_dnv_cnt_cmrt":"0.00","ftlt_rate":"0.00","injpsn_cnt":"44","injpsn_cnt_cmrt":"1.12","tot_acc_cnt":"3856","tot_dth_dnv_cnt":"20","tot_injpsn_cnt":"3942"},{"std_year":"2019","sido_sgg_nm":"서울특별시 강남구","acc_cl_nm":"스쿨존내어린이사고","acc_cnt":"6","acc_cnt_cmrt":"1.06","dth_dnv_cnt":"0","dth_dnv_cnt_cmrt":"0.00","ftlt_rate":"0.00","injpsn_cnt":"6","injpsn_cnt_cmrt":"1.02","tot_acc_cnt":"567","tot_dth_dnv_cnt":"6","tot_injpsn_cnt":"589"},{"std_year":"2019","sido_sgg_nm":"서울특별시 강남구","acc_cl_nm":"고령운전자사고","acc_cnt":"457","acc_cnt_cmrt":"1.37","dth_dnv_cnt":"2","dth_dnv_cnt_cmrt":"0.26","ftlt_rate":"0.44","injpsn_cnt":"613","injpsn_cnt_cmrt":"1.27","tot_acc_cnt":"33239","tot_dth_dnv_cnt":"769","tot_injpsn_cnt":"48223"},{"std_year":"2019","sido_sgg_nm":"서울특별시 강남구","acc_cl_nm":"고령보행자사고","acc_cnt":"91","acc_cnt_cmrt":"0.74","dth_dnv_cnt":"5","dth_dnv_cnt_cmrt":"0.67","ftlt_rate":"5.49","injpsn_cnt":"87","injpsn_cnt_cmrt":"0.75","tot_acc_cnt":"12249","tot_dth_dnv_cnt":"743","tot_injpsn_cnt":"11653"},{"std_year":"2019","sido_sgg_nm":"서울특별시 강남구","acc_cl_nm":"개인이동수단(PM)사고","acc_cnt":"36","acc_cnt_cmrt":"8.05","dth_dnv_cnt":"0","dth_dnv_cnt_cmrt":"0.00","ftlt_rate":"0.00","injpsn_cnt":"38","injpsn_cnt_cmrt":"8.03","tot_acc_cnt":"447","tot_dth_dnv_cnt":"8","tot_injpsn_cnt":"473"},{"std_year":"2019","sido_sgg_nm":"서울특별시 강남구","acc_cl_nm":"뺑소니사고","acc_cnt":"65","acc_cnt_cmrt":"0.91","dth_dnv_cnt":"0","dth_dnv_cnt_cmrt":"0.00","ftlt_rate":"0.00","injpsn_cnt":"107","injpsn_cnt_cmrt":"1.04","tot_acc_cnt":"7129","tot_dth_dnv_cnt":"90","tot_injpsn_cnt":"10285"},{"std_year":"2019","sido_sgg_nm":"서울특별시 강남구","acc_cl_nm":"무면허사고","acc_cnt":"66","acc_cnt_cmrt":"1.27","dth_dnv_cnt":"0","dth_dnv_cnt_cmrt":"0.00","ftlt_rate":"0.00","injpsn_cnt":"87","injpsn_cnt_cmrt":"1.17","tot_acc_cnt":"5177","tot_dth_dnv_cnt":"163","tot_injpsn_cnt":"7445"}]},"totalCount":13, ...

# %%
import requests

url = 'http://apis.data.go.kr/B552061/lgStat/getRestLgStat'

params = {
    "ServiceKey" : 'HCnD0rtW2xL5JgkUNzOEFPuVQO9FxnqdTxFgkAkNYh2eacEW62WkpsWVn7W+UoQNKJXa1HIc8IR9t6ZkI4wzIA=='
    , 'searchYearCd': 2019
    , 'siDo': ''
    , 'guGun': ''
    , 'type': 'json'
    , 'numOfRows': 50000
    , 'pageNo': 1
}

res = requests.get(url, params = params)
print(res.status_code)
print(res.text)
# Out:
# 200
# {"resultCode":"00","resultMsg":"NORMAL_CODE","items":{"item":[{"std_year":"2019","sido_sgg_nm":"강원도","acc_cl_nm":"전체사고","acc_cnt":"7554","acc_cnt_cmrt":"3.29","dth_dnv_cnt":"185","dth_dnv_cnt_cmrt":"5.52","ftlt_rate":"2.45","injpsn_cnt":"11752","injpsn_cnt_cmrt":"3.44","tot_acc_cnt":"229600","tot_dth_dnv_cnt":"3349","tot_injpsn_cnt":"341712","pop_100k":"498.08","car_10k":"80.18","cnt_027_01":"52","cnt_027_02":"498","cnt_027_03":"727","cnt_027_04":"647","cnt_027_05":"4040","cnt_027_06":"639","cnt_027_07":"343","cnt_027_99":"608","cnt_014_01":"1372","cnt_014_02":"5839","cnt_014_03":"342","cnt_014_04":"1"},{"std_year":"2019","sido_sgg_nm":"강원도","acc_cl_nm":"어린이사고","acc_cnt":"367","acc_cnt_cmrt":"3.32","dth_dnv_cnt":"3","dth_dnv_cnt_cmrt":"10.71","ftlt_rate":"0.82","injpsn_cnt":"477","injpsn_cnt_cmrt":"3.38","tot_acc_cnt":"11054","tot_dth_dnv_cnt":"28","tot_injpsn_cnt":"14115"},{"std_year":"2019","sido_sgg_nm":"강원도","acc_cl_nm":"고령자사고","acc_cnt":"1584","acc_cnt_cmrt":"3.90","dth_dnv_cnt":"77","dth_dnv_cnt_cmrt":"5.06","ftlt_rate":"4.86","injpsn_cnt":"1812","injpsn_cnt_cmrt":"4.08","tot_acc_cnt":"40645","tot_dth_dnv_cnt":"1523","tot_injpsn_cnt":"44390"},{"std_year":"2019","sido_sgg_nm":"강원도","acc_cl_nm":"보행자사고","acc_cnt":"1390","acc_cnt_cmrt":"2.98","dth_dnv_cnt":"64","dth_dnv_cnt_cmrt":"4.92","ftlt_rate":"4.60","injpsn_cnt":"1378","injpsn_cnt_cmrt":"2.92","tot_acc_cnt":"46682","tot_dth_dnv_cnt":"1302","tot_injpsn_cnt":"47200"},{"std_year":"2019","sido_sgg_nm":"강원도","acc_cl_nm":"자전거사고","acc_cnt":"82","acc_cnt_cmrt":"1.46","dth_dnv_cnt":"2","dth_dnv_cnt_cmrt":"2.53","ftlt_rate":"2.44","injpsn_cnt":"84","injpsn_cnt_cmrt":"1.40","tot_acc_cnt":"5633","tot_dth_dnv_cnt":"79","tot_injpsn_cnt":"6020"},{"std_year":"2019","sido_sgg_nm":"강원도","acc_cl_nm":"야간사고","acc_cnt":"2551","acc_cnt_cmrt":"2.80","dth_dnv_cnt":"82","dth_dnv_cnt_cmrt":"5.13","ftlt_rate":"3.21","injpsn_cnt":"3843","injpsn_cnt_cmrt":"2.85","tot_acc_cnt":"91067","tot_dth_dnv_cnt":"1599","tot_injpsn_cnt":"134686"},{"std_year":"2019","sido_sgg_nm":"강원도","acc_cl_nm":"어린이보행사고","acc_cnt":"103","acc_cnt_cmrt":"2.67","dth_dnv_cnt":"2","dth_dnv_cnt_cmrt":"10.00","ftlt_rate":"1.94","injpsn_cnt":"103","injpsn_cnt_cmrt":"2.61","tot_acc_cnt":"3856","tot_dth_dnv_cnt":"20","tot_injpsn_cnt":"3942"},{"std_year":"2019","sido_sgg_nm":"강원도","acc_cl_nm":"스쿨존내어린이사고","acc_cnt":"13","acc_cnt_cmrt":"2.29","dth_dnv_cnt":"1","dth_dnv_cnt_cmrt":"16.67","ftlt_rate":"7.69","injpsn_cnt":"13","injpsn_cnt_cmrt":"2.21","tot_acc_cnt":"567","tot_dth_dnv_cnt":"6","tot_injpsn_cnt":"589"},{"std_year":"2019","sido_sgg_nm":"강원도","acc_cl_nm":"고령운전자사고","acc_cnt":"1260","acc_cnt_cmrt":"3.79","dth_dnv_cnt":"41","dth_dnv_cnt_cmrt":"5.33","ftlt_rate":"3.25","injpsn_cnt":"1920","injpsn_cnt_cmrt":"3.98","tot_acc_cnt":"33239","tot_dth_dnv_cnt":"769","tot_injpsn_cnt":"48223"},{"std_year":"2019","sido_sgg_nm":"강원도","acc_cl_nm":"고령보행자사고","acc_cnt":"431","acc_cnt_cmrt":"3.52","dth_dnv_cnt":"40","dth_dnv_cnt_cmrt":"5.38","ftlt_rate":"9.28","injpsn_cnt":"403","injpsn_cnt_cmrt":"3.46","tot_acc_cnt":"12249","tot_dth_dnv_cnt":"743","tot_injpsn_cnt":"11653"},{"std_year":"2019","sido_sgg_nm":"강원도","acc_cl_nm":"개인이동수단(PM)사고","acc_cnt":"6","acc_cnt_cmrt":"1.34","dth_dnv_cnt":"0","dth_dnv_cnt_cmrt":"0.00","ftlt_rate":"0.00","injpsn_cnt":"6","injpsn_cnt_cmrt":"1.27","tot_acc_cnt":"447","tot_dth_dnv_cnt":"8","tot_injpsn_cnt":"473"},{"std_year":"2019","sido_sgg_nm":"강원도","acc_cl_nm":"뺑소니사고","acc_cnt":"193","acc_cnt_cmrt":"2.71","dth_dnv_cnt":"3","dth_dnv_cnt_cmrt":"3.33","ftlt_rate":"1.55","injpsn_cnt":"292","injpsn_cnt_cmrt":"2.84","tot_acc_cnt":"7129","tot_dth_dnv_cnt":"90","tot_injpsn_cnt":"10285"},{"std_year":"2019","sido_sgg_nm":"강원도","acc_cl_nm":"무면허사고","acc_cnt":"147","acc_cnt_cmrt":"2.84","dth_dnv_cnt":"8","dth_dnv_cnt_cmrt":"4.91","ftlt_rate":"5.44","injpsn_cnt":"225","injpsn_cnt_cmrt":"3.02","tot_acc_cnt":"5177","tot_dth_dnv_cnt":"163","tot_injpsn_cnt":"7445"},{"std_year":"2019","sido_sgg_nm":"강원도 강릉시","acc_cl_nm":"전체사고","acc_cnt": ...

# %%
import pandas as pd
# from pandas import DataFrame

data = res.json()['items']['item']
df = pd.DataFrame(data)

df
# Out:
#      std_year sido_sgg_nm     acc_cl_nm acc_cnt acc_cnt_cmrt dth_dnv_cnt  \
# 0        2019         강원도          전체사고    7554         3.29         185
# 1        2019         강원도         어린이사고     367         3.32           3
# 2        2019         강원도         고령자사고    1584         3.90          77
# 3        2019         강원도         보행자사고    1390         2.98          64
# 4        2019         강원도         자전거사고      82         1.46           2
# ...       ...         ...           ...     ...          ...         ...
# 2947     2019    충청북도 충주시       고령운전자사고     254         0.76           4
# 2948     2019    충청북도 충주시       고령보행자사고      66         0.54           5
# 2949     2019    충청북도 충주시  개인이동수단(PM)사고       1         0.22           1
# 2950     2019    충청북도 충주시         뺑소니사고      40         0.56           1
# 2951     2019    충청북도 충주시         무면허사고      22         0.42           1
#
#      dth_dnv_cnt_cmrt ftlt_rate injpsn_cnt injpsn_cnt_cmrt  ... cnt_027_03  \
# 0                5.52      2.45      11752            3.44  ...        727
# 1               10.71      0.82        477            3.38  ...        NaN
# 2                5.06      4.86       1812            4.08  ...        NaN
# 3                4.92      4.60       1378            2.92  ...        NaN
# 4                2.53      2.44         84            1.40  ...        NaN
# ...               ...       ...        ...             ...  ...        ...
# 2947             0.52      1.57        452            0.94  ...        NaN
# 2948             0.67      7.58         61            0.52  ...        NaN
# 2949            12.50    100.00          0            0.00  ...        NaN
# 2950             1.11      2.50         53            0.52  ...        NaN
# 2951             0.61      4.55         34            0.46  ...        NaN
#
#      cnt_027_04 cnt_027_05 cnt_027_06 cnt_027_07 cnt_027_99 cnt_014_01  \
# 0           647       4040        639        343        608       1372
# 1           NaN        NaN        NaN        NaN        NaN        NaN
# 2           NaN        NaN        NaN        NaN        NaN        NaN
# 3           NaN        NaN        NaN        NaN        NaN        NaN
# 4           NaN        NaN        NaN        NaN        NaN        NaN
# ...         ...        ...        ...        ...        ...        ...
# 2947        NaN        NaN        NaN        NaN        NaN        NaN
# 2948        NaN        NaN        NaN        NaN        NaN        NaN
# 2949        NaN        NaN        NaN        NaN        NaN        NaN
# 2950        NaN        NaN        NaN        NaN        NaN        NaN
# 2951        NaN        NaN        NaN        NaN        NaN        NaN
#
#      cnt_014_02 cnt_014_03 cnt_014_04
# 0          5839        342          1
# 1           NaN        NaN        NaN
# 2           NaN        NaN        NaN
# 3           NaN        NaN        NaN
# 4           NaN        NaN        NaN
# ...         ...        ...        ...
# 2947        NaN        NaN        NaN
# 2948        NaN        NaN        NaN
# 2949        NaN        NaN        NaN
# 2950        NaN        NaN        NaN
# 2951        NaN        NaN        NaN
#
# [2952 rows x 27 columns]

# %%
df.head() # 요약정보 상위5
# Out:
#   std_year sido_sgg_nm acc_cl_nm acc_cnt acc_cnt_cmrt dth_dnv_cnt  \
# 0     2019         강원도      전체사고    7554         3.29         185
# 1     2019         강원도     어린이사고     367         3.32           3
# 2     2019         강원도     고령자사고    1584         3.90          77
# 3     2019         강원도     보행자사고    1390         2.98          64
# 4     2019         강원도     자전거사고      82         1.46           2
#
#   dth_dnv_cnt_cmrt ftlt_rate injpsn_cnt injpsn_cnt_cmrt  ... cnt_027_03  \
# 0             5.52      2.45      11752            3.44  ...        727
# 1            10.71      0.82        477            3.38  ...        NaN
# 2             5.06      4.86       1812            4.08  ...        NaN
# 3             4.92      4.60       1378            2.92  ...        NaN
# 4             2.53      2.44         84            1.40  ...        NaN
#
#   cnt_027_04 cnt_027_05 cnt_027_06 cnt_027_07 cnt_027_99 cnt_014_01  \
# 0        647       4040        639        343        608       1372
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN        NaN
#
#   cnt_014_02 cnt_014_03 cnt_014_04
# 0       5839        342          1
# 1        NaN        NaN        NaN
# 2        NaN        NaN        NaN
# 3        NaN        NaN        NaN
# 4        NaN        NaN        NaN
#
# [5 rows x 27 columns]

# %%
df.tail() # 요약정보 하위5
# Out:
#      std_year sido_sgg_nm     acc_cl_nm acc_cnt acc_cnt_cmrt dth_dnv_cnt  \
# 2947     2019    충청북도 충주시       고령운전자사고     254         0.76           4
# 2948     2019    충청북도 충주시       고령보행자사고      66         0.54           5
# 2949     2019    충청북도 충주시  개인이동수단(PM)사고       1         0.22           1
# 2950     2019    충청북도 충주시         뺑소니사고      40         0.56           1
# 2951     2019    충청북도 충주시         무면허사고      22         0.42           1
#
#      dth_dnv_cnt_cmrt ftlt_rate injpsn_cnt injpsn_cnt_cmrt  ... cnt_027_03  \
# 2947             0.52      1.57        452            0.94  ...        NaN
# 2948             0.67      7.58         61            0.52  ...        NaN
# 2949            12.50    100.00          0            0.00  ...        NaN
# 2950             1.11      2.50         53            0.52  ...        NaN
# 2951             0.61      4.55         34            0.46  ...        NaN
#
#      cnt_027_04 cnt_027_05 cnt_027_06 cnt_027_07 cnt_027_99 cnt_014_01  \
# 2947        NaN        NaN        NaN        NaN        NaN        NaN
# 2948        NaN        NaN        NaN        NaN        NaN        NaN
# 2949        NaN        NaN        NaN        NaN        NaN        NaN
# 2950        NaN        NaN        NaN        NaN        NaN        NaN
# 2951        NaN        NaN        NaN        NaN        NaN        NaN
#
#      cnt_014_02 cnt_014_03 cnt_014_04
# 2947        NaN        NaN        NaN
# 2948        NaN        NaN        NaN
# 2949        NaN        NaN        NaN
# 2950        NaN        NaN        NaN
# 2951        NaN        NaN        NaN
#
# [5 rows x 27 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2952 entries, 0 to 2951
# Data columns (total 27 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   std_year          2952 non-null   object
#  1   sido_sgg_nm       2952 non-null   object
#  2   acc_cl_nm         2952 non-null   object
#  3   acc_cnt           2952 non-null   object
#  4   acc_cnt_cmrt      2952 non-null   object
#  5   dth_dnv_cnt       2952 non-null   object
#  6   dth_dnv_cnt_cmrt  2952 non-null   object
#  7   ftlt_rate         2952 non-null   object
#  8   injpsn_cnt        2952 non-null   object
#  9   injpsn_cnt_cmrt   2952 non-null   object
#  10  tot_acc_cnt       2952 non-null   object
#  11  tot_dth_dnv_cnt   2952 non-null   object
#  12  tot_injpsn_cnt    2952 non-null   object
#  13  pop_100k          245 non-null    object
#  14  car_10k           245 non-null    object
#  15  cnt_027_01        245 non-null    object
#  16  cnt_027_02        245 non-null    object
#  17  cnt_027_03        245 non-null    object
#  18  cnt_027_04        245 non-null    object
#  19  cnt_027_05        245 non-null    object
#  20  cnt_027_06        245 non-null    object
#  21  cnt_027_07        245 non-null    object
#  22  cnt_027_99        245 non-null    object
#  23  cnt_014_01        245 non-null    object
#  24  cnt_014_02        245 non-null    object
#  25  cnt_014_03        245 non-null    object
#  26  cnt_014_04        245 non-null    object
# dtypes: object(27)
# memory usage: 622.8+ KB

# %%
df.describe() # 숫자형과 문자형 다르게 출력
# Out:
#        std_year sido_sgg_nm acc_cl_nm acc_cnt acc_cnt_cmrt dth_dnv_cnt  \
# count      2952        2952      2952    2952         2952        2952
# unique        1         245        13     704          371          99
# top        2019     경기도 수원시     고령자사고       1         0.18           0
# freq       2952          13       245     129           74        1194
#
#        dth_dnv_cnt_cmrt ftlt_rate injpsn_cnt injpsn_cnt_cmrt  ... cnt_027_03  \
# count              2952      2952       2952            2952  ...        245
# unique              218       625        793             365  ...        165
# top                0.00      0.00          1            0.03  ...          7
# freq               1194      1194        121              85  ...          6
#
#        cnt_027_04 cnt_027_05 cnt_027_06 cnt_027_07 cnt_027_99 cnt_014_01  \
# count         245        245        245        245        245        245
# unique        150        211        133        104        145        184
# top             9        383          1          1         46         30
# freq            9          3          8         14          5          5
#
#        cnt_014_02 cnt_014_03 cnt_014_04
# count         245        245        245
# unique        232        104          3
# top           476         34          0
# freq            2          8        232
#
# [4 rows x 27 columns]

# %%
df.to_excel('교통사고통계.xlsx')

# %%
# 전체사고 로우 제외
cond = df['acc_cl_nm'] != '전체사고'
cond
# Out:
# 0       False
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 2947     True
# 2948     True
# 2949     True
# 2950     True
# 2951     True
# Name: acc_cl_nm, Length: 2952, dtype: bool

# %%
df = df[cond]
df
# Out:
#      std_year sido_sgg_nm     acc_cl_nm acc_cnt acc_cnt_cmrt dth_dnv_cnt  \
# 1        2019         강원도         어린이사고     367         3.32           3
# 2        2019         강원도         고령자사고    1584         3.90          77
# 3        2019         강원도         보행자사고    1390         2.98          64
# 4        2019         강원도         자전거사고      82         1.46           2
# 5        2019         강원도          야간사고    2551         2.80          82
# ...       ...         ...           ...     ...          ...         ...
# 2947     2019    충청북도 충주시       고령운전자사고     254         0.76           4
# 2948     2019    충청북도 충주시       고령보행자사고      66         0.54           5
# 2949     2019    충청북도 충주시  개인이동수단(PM)사고       1         0.22           1
# 2950     2019    충청북도 충주시         뺑소니사고      40         0.56           1
# 2951     2019    충청북도 충주시         무면허사고      22         0.42           1
#
#      dth_dnv_cnt_cmrt ftlt_rate injpsn_cnt injpsn_cnt_cmrt  ... cnt_027_03  \
# 1               10.71      0.82        477            3.38  ...        NaN
# 2                5.06      4.86       1812            4.08  ...        NaN
# 3                4.92      4.60       1378            2.92  ...        NaN
# 4                2.53      2.44         84            1.40  ...        NaN
# 5                5.13      3.21       3843            2.85  ...        NaN
# ...               ...       ...        ...             ...  ...        ...
# 2947             0.52      1.57        452            0.94  ...        NaN
# 2948             0.67      7.58         61            0.52  ...        NaN
# 2949            12.50    100.00          0            0.00  ...        NaN
# 2950             1.11      2.50         53            0.52  ...        NaN
# 2951             0.61      4.55         34            0.46  ...        NaN
#
#      cnt_027_04 cnt_027_05 cnt_027_06 cnt_027_07 cnt_027_99 cnt_014_01  \
# 1           NaN        NaN        NaN        NaN        NaN        NaN
# 2           NaN        NaN        NaN        NaN        NaN        NaN
# 3           NaN        NaN        NaN        NaN        NaN        NaN
# 4           NaN        NaN        NaN        NaN        NaN        NaN
# 5           NaN        NaN        NaN        NaN        NaN        NaN
# ...         ...        ...        ...        ...        ...        ...
# 2947        NaN        NaN        NaN        NaN        NaN        NaN
# 2948        NaN        NaN        NaN        NaN        NaN        NaN
# 2949        NaN        NaN        NaN        NaN        NaN        NaN
# 2950        NaN        NaN        NaN        NaN        NaN        NaN
# 2951        NaN        NaN        NaN        NaN        NaN        NaN
#
#      cnt_014_02 cnt_014_03 cnt_014_04
# 1           NaN        NaN        NaN
# 2           NaN        NaN        NaN
# 3           NaN        NaN        NaN
# 4           NaN        NaN        NaN
# 5           NaN        NaN        NaN
# ...         ...        ...        ...
# 2947        NaN        NaN        NaN
# 2948        NaN        NaN        NaN
# 2949        NaN        NaN        NaN
# 2950        NaN        NaN        NaN
# 2951        NaN        NaN        NaN
#
# [2707 rows x 27 columns]

# %%
df = df.iloc[:, :13].copy()
df
# Out:
#       std_year sido_sgg_nm     acc_cl_nm  acc_cnt  acc_cnt_cmrt  dth_dnv_cnt  \
# 1         2019         강원도         어린이사고      367          3.32            3
# 2         2019         강원도         고령자사고     1584          3.90           77
# 3         2019         강원도         보행자사고     1390          2.98           64
# 4         2019         강원도         자전거사고       82          1.46            2
# 5         2019         강원도          야간사고     2551          2.80           82
# ...        ...         ...           ...      ...           ...          ...
# 2947      2019    충청북도 충주시       고령운전자사고      254          0.76            4
# 2948      2019    충청북도 충주시       고령보행자사고       66          0.54            5
# 2949      2019    충청북도 충주시  개인이동수단(PM)사고        1          0.22            1
# 2950      2019    충청북도 충주시         뺑소니사고       40          0.56            1
# 2951      2019    충청북도 충주시         무면허사고       22          0.42            1
#
#       dth_dnv_cnt_cmrt  ftlt_rate  injpsn_cnt  injpsn_cnt_cmrt  tot_acc_cnt  \
# 1                10.71       0.82         477             3.38        11054
# 2                 5.06       4.86        1812             4.08        40645
# 3                 4.92       4.60        1378             2.92        46682
# 4                 2.53       2.44          84             1.40         5633
# 5                 5.13       3.21        3843             2.85        91067
# ...                ...        ...         ...              ...          ...
# 2947              0.52       1.57         452             0.94        33239
# 2948              0.67       7.58          61             0.52        12249
# 2949             12.50     100.00           0             0.00          447
# 2950              1.11       2.50          53             0.52         7129
# 2951              0.61       4.55          34             0.46         5177
#
#       tot_dth_dnv_cnt  tot_injpsn_cnt
# 1                  28           14115
# 2                1523           44390
# 3                1302           47200
# 4                  79            6020
# 5                1599          134686
# ...               ...             ...
# 2947              769           48223
# 2948              743           11653
# 2949                8             473
# 2950               90           10285
# 2951              163            7445
#
# [2707 rows x 13 columns]

# %%
df['std_year'] = df['std_year'].astype('int')
df['acc_cnt'] = df['acc_cnt'].astype('int')
df['acc_cnt_cmrt'] = df['acc_cnt_cmrt'].astype('float')
df['dth_dnv_cnt'] = df['dth_dnv_cnt'].astype('int')
df['dth_dnv_cnt_cmrt'] = df['dth_dnv_cnt_cmrt'].astype('float')
df['ftlt_rate'] = df['ftlt_rate'].astype('float')
df['injpsn_cnt'] = df['injpsn_cnt'].astype('int')
df['injpsn_cnt_cmrt'] = df['injpsn_cnt_cmrt'].astype('float')
df['tot_acc_cnt'] = df['tot_acc_cnt'].astype('int')
df['tot_dth_dnv_cnt'] = df['tot_dth_dnv_cnt'].astype('int')
df['tot_injpsn_cnt'] = df['tot_injpsn_cnt'].astype('int')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2707 entries, 1 to 2951
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   std_year          2707 non-null   int32
#  1   sido_sgg_nm       2707 non-null   object
#  2   acc_cl_nm         2707 non-null   object
#  3   acc_cnt           2707 non-null   int32
#  4   acc_cnt_cmrt      2707 non-null   float64
#  5   dth_dnv_cnt       2707 non-null   int32
#  6   dth_dnv_cnt_cmrt  2707 non-null   float64
#  7   ftlt_rate         2707 non-null   float64
#  8   injpsn_cnt        2707 non-null   int32
#  9   injpsn_cnt_cmrt   2707 non-null   float64
#  10  tot_acc_cnt       2707 non-null   int32
#  11  tot_dth_dnv_cnt   2707 non-null   int32
#  12  tot_injpsn_cnt    2707 non-null   int32
# dtypes: float64(4), int32(7), object(2)
# memory usage: 222.1+ KB

# %%
import requests
import pandas as pd

df_total = pd.DataFrame()
url = 'http://apis.data.go.kr/B552061/lgStat/getRestLgStat'

for year in range(2010,2021):
    print(f"Year: {year}")
    
    params = {
    "ServiceKey" : 'HCnD0rtW2xL5JgkUNzOEFPuVQO9FxnqdTxFgkAkNYh2eacEW62WkpsWVn7W+UoQNKJXa1HIc8IR9t6ZkI4wzIA=='
    , 'searchYearCd': year
    , 'siDo': 1100 # 서울 전체
    , 'guGun': '' # 서울 전체 구
    , 'type': 'json'
    , 'numOfRows': 5000
    , 'pageNo': 1
    }
    
    res = requests.get(url, params = params)
#     print(res.json())
    
    data = res.json()['items']['item']
    df = pd.DataFrame(data=data)
    
    cond = df['acc_cl_nm'] != '전체사고'
    df = df[cond]
    df = df.iloc[:, :13].copy()
    
    df['std_year'] = df['std_year'].astype('int')
    df['acc_cnt'] = df['acc_cnt'].astype('int')
    df['acc_cnt_cmrt'] = df['acc_cnt_cmrt'].astype('float')
    df['dth_dnv_cnt'] = df['dth_dnv_cnt'].astype('int')
    df['dth_dnv_cnt_cmrt'] = df['dth_dnv_cnt_cmrt'].astype('float')
    df['ftlt_rate'] = df['ftlt_rate'].astype('float')
    df['injpsn_cnt'] = df['injpsn_cnt'].astype('int')
    df['injpsn_cnt_cmrt'] = df['injpsn_cnt_cmrt'].astype('float')
    df['tot_acc_cnt'] = df['tot_acc_cnt'].astype('int')
    df['tot_dth_dnv_cnt'] = df['tot_dth_dnv_cnt'].astype('int')
    df['tot_injpsn_cnt'] = df['tot_injpsn_cnt'].astype('int')
    
    df_total = df_total.append(df)
#     print(df_total)
df_total = df_total.set_index('std_year')
df_total
# Out:
# Year: 2010
# Year: 2011
# Year: 2012
# Year: 2013
# Year: 2014
# Year: 2015
# Year: 2016
# Year: 2017
# Year: 2018
# Year: 2019
# Year: 2020
#          sido_sgg_nm     acc_cl_nm  acc_cnt  acc_cnt_cmrt  dth_dnv_cnt  \
# std_year
# 2010           서울특별시         어린이사고     1930         13.69           14
# 2010           서울특별시         고령자사고     3528         13.67          125
# 2010           서울특별시         보행자사고    10946         21.70          228
# 2010           서울특별시         자전거사고      998         37.48           12
# 2010           서울특별시          야간사고    21889         19.69          239
# ...              ...           ...      ...           ...          ...
# 2020       서울특별시 중랑구       고령운전자사고      219          0.70            2
# 2020       서울특별시 중랑구       고령보행자사고       99          1.02            3
# 2020       서울특별시 중랑구  개인이동수단(PM)사고        5          0.56            0
# 2020       서울특별시 중랑구         뺑소니사고       26          0.35            0
# 2020       서울특별시 중랑구         무면허사고       24          0.45            0
#
#           dth_dnv_cnt_cmrt  ftlt_rate  injpsn_cnt  injpsn_cnt_cmrt  \
# std_year
# 2010                 11.11       0.73        2154            12.54
# 2010                  7.13       3.54        3584            13.08
# 2010                 10.95       2.08       11233            22.07
# 2010                 16.44       1.20        1036            37.93
# 2010                  7.98       1.09       32801            18.88
# ...                    ...        ...         ...              ...
# 2020                  0.28       0.91         277             0.63
# 2020                  0.48       3.03          97             1.05
# 2020                  0.00       0.00           5             0.51
# 2020                  0.00       0.00          40             0.38
# 2020                  0.00       0.00          34             0.45
#
#           tot_acc_cnt  tot_dth_dnv_cnt  tot_injpsn_cnt
# std_year
# 2010            14095              126           17178
# 2010            25810             1752           27394
# 2010            50431             2082           50899
# 2010             2663               73            2731
# 2010           111159             2996          173695
# ...               ...              ...             ...
# 2020            31072              720           44269
# 2020             9739              628            9233
# 2020              897               10             985
# 2020             7418               97           10419
# 2020             5307              169            7597
#
# [3211 rows x 12 columns]

# %%
def sigu(x):
    y = len(x.split())
    return y
#함수를 적용하는 함수 apply(함수명), 사용자 정의 함수 사용 가능
cond = df_total['sido_sgg_nm'].apply(sigu) == 1
print(cond)
# Out:
# std_year
# 2010     True
# 2010     True
# 2010     True
# 2010     True
# 2010     True
#         ...
# 2020    False
# 2020    False
# 2020    False
# 2020    False
# 2020    False
# Name: sido_sgg_nm, Length: 3211, dtype: bool

# %%
df_total = df_total.loc[~cond]   # ~: not 의 의미
df_total
# Out:
#          sido_sgg_nm     acc_cl_nm  acc_cnt  acc_cnt_cmrt  dth_dnv_cnt  \
# std_year
# 2010       서울특별시 강남구         어린이사고       79          0.56            0
# 2010       서울특별시 강남구         고령자사고      157          0.61            3
# 2010       서울특별시 강남구         보행자사고      753          1.49           12
# 2010       서울특별시 강남구         자전거사고       25          0.94            0
# 2010       서울특별시 강남구          야간사고     1994          1.79           18
# ...              ...           ...      ...           ...          ...
# 2020       서울특별시 중랑구       고령운전자사고      219          0.70            2
# 2020       서울특별시 중랑구       고령보행자사고       99          1.02            3
# 2020       서울특별시 중랑구  개인이동수단(PM)사고        5          0.56            0
# 2020       서울특별시 중랑구         뺑소니사고       26          0.35            0
# 2020       서울특별시 중랑구         무면허사고       24          0.45            0
#
#           dth_dnv_cnt_cmrt  ftlt_rate  injpsn_cnt  injpsn_cnt_cmrt  \
# std_year
# 2010                  0.00       0.00          91             0.53
# 2010                  0.17       1.91         157             0.57
# 2010                  0.58       1.59         780             1.53
# 2010                  0.00       0.00          29             1.06
# 2010                  0.60       0.90        3073             1.77
# ...                    ...        ...         ...              ...
# 2020                  0.28       0.91         277             0.63
# 2020                  0.48       3.03          97             1.05
# 2020                  0.00       0.00           5             0.51
# 2020                  0.00       0.00          40             0.38
# 2020                  0.00       0.00          34             0.45
#
#           tot_acc_cnt  tot_dth_dnv_cnt  tot_injpsn_cnt
# std_year
# 2010            14095              126           17178
# 2010            25810             1752           27394
# 2010            50431             2082           50899
# 2010             2663               73            2731
# 2010           111159             2996          173695
# ...               ...              ...             ...
# 2020            31072              720           44269
# 2020             9739              628            9233
# 2020              897               10             985
# 2020             7418               97           10419
# 2020             5307              169            7597
#
# [3086 rows x 12 columns]

# %%
df_total.groupby('acc_cl_nm').sum().sort_values(by='acc_cnt',ascending=False)
# Out:
#               acc_cnt  acc_cnt_cmrt  dth_dnv_cnt  dth_dnv_cnt_cmrt  ftlt_rate  \
# acc_cl_nm
# 야간사고           374462        411.18         3234            202.51     254.54
# 보행자사고          219758        471.13         3168            243.10     430.21
# 고령자사고          130064        319.99         2266            149.16     519.31
# 고령운전자사고        129492        389.40         1078            140.14     253.00
# 고령보행자사고         49896        407.22         1584            212.74     974.71
# 자전거사고           38852        689.70          242            306.57     244.97
# 어린이사고           32450        293.37           66            235.62      41.58
# 뺑소니사고           15862        222.31          110            122.21     222.31
# 어린이보행사고         13948        361.68           66            330.00      84.48
# 무면허사고           12254        236.72           66             40.37     119.90
# 개인이동수단(PM)사고     2948        659.34           22            275.00     283.25
# 스쿨존내어린이사고        2508        442.53           44            733.37     225.50
#
#               injpsn_cnt  injpsn_cnt_cmrt  tot_acc_cnt  tot_dth_dnv_cnt  \
# acc_cl_nm
# 야간사고              524040           389.07     26045162           457314
# 보행자사고             224334           475.42     13351052           372372
# 고령자사고             136400           307.12     11624470           435578
# 고령운전자사고           173382           359.48      9506354           219934
# 고령보행자사고            49082           421.30      3503214           212498
# 자전거사고              42900           712.58      1611038            22594
# 어린이사고              38940           275.99      3161444             8008
# 뺑소니사고              24068           233.97      2038894            25740
# 어린이보행사고            14102           358.05      1102816             5720
# 무면허사고              17512           235.51      1480622            46618
# 개인이동수단(PM)사고        3058           646.25       127842             2288
# 스쿨존내어린이사고           2530           429.77       143451             1518
#
#               tot_injpsn_cnt
# acc_cl_nm
# 야간사고                38520196
# 보행자사고               13499200
# 고령자사고               12695540
# 고령운전자사고             13791778
# 고령보행자사고              3332758
# 자전거사고                1721720
# 어린이사고                4036890
# 뺑소니사고                2941510
# 어린이보행사고              1127412
# 무면허사고                2129270
# 개인이동수단(PM)사고          135278
# 스쿨존내어린이사고             149017

# %%
df_total_acc_cnt = df_total.groupby('acc_cl_nm').sum().sort_values(by='acc_cnt',ascending=False)['acc_cnt']
df_total_acc_cnt
# Out:
# acc_cl_nm
# 야간사고            211041
# 보행자사고           115517
# 고령자사고            53652
# 고령운전자사고          45844
# 고령보행자사고          22412
# 자전거사고            19075
# 어린이사고            16965
# 뺑소니사고            11291
# 무면허사고             8231
# 어린이보행사고           7915
# 스쿨존내어린이사고         1034
# 개인이동수단(PM)사고       600
# Name: acc_cnt, dtype: int32

# %%
import matplotlib.pyplot as plt
i = df_total_acc_cnt 
j = df_total['acc_cl_nm']

plt.pie(i, labels = i.index, autopct='%.1f%%')
plt.legend()
plt.show()
# Out:
# C:\Users\CJH\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 50556 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\CJH\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44036 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\CJH\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 49324 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\CJH\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44256 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\CJH\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 48372 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\CJH\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 54665 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\CJH\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51088 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\CJH\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 47161 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\CJH\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 50868 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\CJH\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51204 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\CJH\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44144 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\CJH\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 50612 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\CJH\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 47536 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\CJH\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51060 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\CJH\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 48785 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\CJH\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 49548 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\CJH\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 45768 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\CJH\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 47924 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\CJH\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 47732 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\CJH\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 54728 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\CJH\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 49828 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\CJH\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 53224 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\CJH\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51316 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\CJH\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 45236 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\CJH\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44060 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\CJH\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51064 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\CJH\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 46041 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\CJH\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\CJH\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 45800 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\CJH\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 50556 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\CJH\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 44036 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\CJH\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 49324 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\CJH\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 44256 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\CJH\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 48372 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\CJH\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 54665 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\CJH\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 51088 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\CJH\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 47161 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\CJH\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 50868 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\CJH\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 51204 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\CJH\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 44144 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\CJH\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 50612 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\CJH\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 47536 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\CJH\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 51060 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\CJH\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 48785 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\CJH\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 49548 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\CJH\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 45768 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\CJH\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 47924 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\CJH\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 47732 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\CJH\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 54728 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\CJH\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 49828 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\CJH\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 53224 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\CJH\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 51316 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\CJH\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 45236 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\CJH\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 44060 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\CJH\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 51064 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\CJH\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 46041 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\CJH\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\CJH\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 45800 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
j
# Out:
# std_year
# 2010           어린이사고
# 2010           고령자사고
# 2010           보행자사고
# 2010           자전거사고
# 2010            야간사고
#             ...
# 2020         고령운전자사고
# 2020         고령보행자사고
# 2020    개인이동수단(PM)사고
# 2020           뺑소니사고
# 2020           무면허사고
# Name: acc_cl_nm, Length: 3086, dtype: object

# %%
df_total_acc_cnt
# Out:
# acc_cl_nm
# 야간사고            211041
# 보행자사고           115517
# 고령자사고            53652
# 고령운전자사고          45844
# 고령보행자사고          22412
# 자전거사고            19075
# 어린이사고            16965
# 뺑소니사고            11291
# 무면허사고             8231
# 어린이보행사고           7915
# 스쿨존내어린이사고         1034
# 개인이동수단(PM)사고       600
# Name: acc_cnt, dtype: int32

# %%
df_total['acc_cl_nm']
# Out:
# std_year
# 2010           어린이사고
# 2010           고령자사고
# 2010           보행자사고
# 2010           자전거사고
# 2010            야간사고
#             ...
# 2020         고령운전자사고
# 2020         고령보행자사고
# 2020    개인이동수단(PM)사고
# 2020           뺑소니사고
# 2020           무면허사고
# Name: acc_cl_nm, Length: 3086, dtype: object

# %%
df_total_뺑소니 = df_total.loc[df_total['acc_cl_nm'] == '뺑소니사고']
df_total_뺑소니
# Out:
#          sido_sgg_nm acc_cl_nm  acc_cnt  acc_cnt_cmrt  dth_dnv_cnt  \
# std_year
# 2010       서울특별시 강남구     뺑소니사고      168          1.43            3
# 2010       서울특별시 강동구     뺑소니사고       31          0.26            0
# 2010       서울특별시 강북구     뺑소니사고       33          0.28            1
# 2010       서울특별시 강서구     뺑소니사고       51          0.43            2
# 2010       서울특별시 관악구     뺑소니사고       68          0.58            0
# ...              ...       ...      ...           ...          ...
# 2020       서울특별시 용산구     뺑소니사고       25          0.34            0
# 2020       서울특별시 은평구     뺑소니사고       31          0.42            0
# 2020       서울특별시 종로구     뺑소니사고       31          0.42            0
# 2020        서울특별시 중구     뺑소니사고       14          0.19            0
# 2020       서울특별시 중랑구     뺑소니사고       26          0.35            0
#
#           dth_dnv_cnt_cmrt  ftlt_rate  injpsn_cnt  injpsn_cnt_cmrt  \
# std_year
# 2010                  1.11       1.79         276             1.46
# 2010                  0.00       0.00          60             0.32
# 2010                  0.37       3.03          48             0.25
# 2010                  0.74       3.92          81             0.43
# 2010                  0.00       0.00         114             0.61
# ...                    ...        ...         ...              ...
# 2020                  0.00       0.00          33             0.32
# 2020                  0.00       0.00          38             0.36
# 2020                  0.00       0.00          44             0.42
# 2020                  0.00       0.00          17             0.16
# 2020                  0.00       0.00          40             0.38
#
#           tot_acc_cnt  tot_dth_dnv_cnt  tot_injpsn_cnt
# std_year
# 2010            11729              271           18840
# 2010            11729              271           18840
# 2010            11729              271           18840
# 2010            11729              271           18840
# 2010            11729              271           18840
# ...               ...              ...             ...
# 2020             7418               97           10419
# 2020             7418               97           10419
# 2020             7418               97           10419
# 2020             7418               97           10419
# 2020             7418               97           10419
#
# [275 rows x 12 columns]

# %%
import matplotlib.pyplot as plt
'''
연도별 뺑소니 사고 건수에 대한 추이를 막대 그래프로 그래보세요
'''

df_total_뺑소니.groupby(by='std_year').sum()
plt.bar(df_total_뺑소니.index, df_total_뺑소니['acc_cnt']) # plt.bar([x], [y])
plt.show()

# %%
'''
위 데이터로부터 도출할 수 있는 아이디어를 모아보세요

1. 야간사고가 가장 많은 지역과 적은 지역
2. 과속 건수와 사고 건수의 상관 관계
3. 사망률과 무면허사고

'''
import pandas as pd
import requests

df_total = pd.DataFrame()

url = 'http://apis.data.go.kr/B552061/lgStat/getRestLgStat'

for year in range(2010, 2021):
    print(f"Year: {year}")

    params = {
        "ServiceKey": "2d/kqDK/CUnoxGW/RnHFEpXgrBjB5Pw4MmMqhYKoIvdApLpkThFwjtvksZFh2VcCF8HsGQ0J8G1t7RDcLVaoLg=="
        , "searchYearCd": year
        , "siDo": ''
        , "guGun": ''
        , "type": "json"
        , "numOfRows": 5000
        , "pageNo": 1
    }

    res = requests.get(url, params=params)
#     print(res.json())

    data = res.json()['items']['item']   # [ {}, {}, ..., {} ]
    new_data = []
    
    for d in data:
        # 조건에 해당 하는 데이터 필터링
        if len(d['sido_sgg_nm'].split()) == 1 and d['acc_cl_nm'] == '전체사고':
            new_data.append(d)
        
    df = pd.DataFrame(new_data)
    
    # 데이터 수치화
    df = df.astype({
        'std_year': int,
        'acc_cnt': int,
        'acc_cnt_cmrt': float,
        'dth_dnv_cnt': int,
        'dth_dnv_cnt_cmrt': float,
        'ftlt_rate': float,
        'injpsn_cnt': int,
        'injpsn_cnt_cmrt': float,
        'tot_acc_cnt': int,
        'tot_dth_dnv_cnt': int,
        'tot_injpsn_cnt': int,
        
        'pop_100k': float,
        'car_10k': float,
        'cnt_027_01': int,
        'cnt_027_02': int,
        'cnt_027_03': int,
        'cnt_027_04': int,
        'cnt_027_05': int,
        'cnt_027_06': int,
        'cnt_027_07': int,
        'cnt_027_99': int,
        'cnt_014_01': int,
        'cnt_014_02': int,
        'cnt_014_03': int,
        'cnt_014_04': int
    })
    
    df_total = df_total.append(df)

df_total = df_total.set_index('std_year')
df_total
# Out:
# Year: 2010
# Year: 2011
# Year: 2012
# Year: 2013
# Year: 2014
# Year: 2015
# Year: 2016
# Year: 2017
# Year: 2018
# Year: 2019
# Year: 2020
#          sido_sgg_nm acc_cl_nm  acc_cnt  acc_cnt_cmrt  dth_dnv_cnt  \
# std_year
# 2010             강원도      전체사고     9026          3.98          267
# 2010             경기도      전체사고    43963         19.38         1002
# 2010            경상남도      전체사고    14274          6.29          487
# 2010            경상북도      전체사고    16498          7.27          624
# 2010           광주광역시      전체사고     8894          3.92          126
# ...              ...       ...      ...           ...          ...
# 2020            전라남도      전체사고     9816          4.68          273
# 2020            전라북도      전체사고     6451          3.08          220
# 2020             제주도      전체사고     4030          1.92           68
# 2020            충청남도      전체사고     8952          4.27          261
# 2020            충청북도      전체사고     8398          4.01          171
#
#           dth_dnv_cnt_cmrt  ftlt_rate  injpsn_cnt  injpsn_cnt_cmrt  \
# std_year
# 2010                  4.85       2.96       15693             4.45
# 2010                 18.20       2.28       70818            20.09
# 2010                  8.85       3.41       21620             6.13
# 2010                 11.34       3.78       26077             7.40
# 2010                  2.29       1.42       14618             4.15
# ...                    ...        ...         ...              ...
# 2020                  8.86       2.78       15645             5.11
# 2020                  7.14       3.41        9778             3.19
# 2020                  2.21       1.69        6131             2.00
# 2020                  8.47       2.92       13381             4.37
# 2020                  5.55       2.04       13238             4.32
#
#           tot_acc_cnt  ...  cnt_027_03  cnt_027_04  cnt_027_05  cnt_027_06  \
# std_year               ...
# 2010           226878  ...         821         666        5080         659
# 2010           226878  ...        6207        3579       25130        2773
# 2010           226878  ...        1331        1029        7995        1219
# 2010           226878  ...        1142         724       10772        1164
# 2010           226878  ...        1256        1426        4263         815
# ...               ...  ...         ...         ...         ...         ...
# 2020           209654  ...         826         570        5672         869
# 2020           209654  ...         975         385        3330         326
# 2020           209654  ...         333         472        1936         275
# 2020           209654  ...        1005         545        5099         574
# 2020           209654  ...         983         713        4493         725
#
#           cnt_027_07  cnt_027_99  cnt_014_01  cnt_014_02  cnt_014_03  \
# std_year
# 2010             293         619        1627        6923         476
# 2010            1096        2248        9104       33263        1596
# 2010             465        1159        3029       10514         730
# 2010             383         928        2783       12429        1283
# 2010             222         408        1749        6783         362
# ...              ...         ...         ...         ...         ...
# 2020             175        1081        1455        7639         722
# 2020             274         751        1207        4961         283
# 2020             181         619         711        3018         301
# 2020             266         814        1414        7059         479
# 2020             183         811        1059        6914         425
#
#           cnt_014_04
# std_year
# 2010               0
# 2010               0
# 2010               1
# 2010               3
# 2010               0
# ...              ...
# 2020               0
# 2020               0
# 2020               0
# 2020               0
# 2020               0
#
# [185 rows x 26 columns]

# %%
import matplotlib.pyplot as plt

plt.pie(df_total['cnt_027_01'], labels=df_total['acc_cnt'], autopct='%.1f%%') #scatter([x], [y])
plt.show()

# %%
df_total_야간사고 = df_total_야간사고.groupby(by=['sido_sgg_nm']).sum().sort_values(by='acc_cnt', ascending = False)
df_total_야간사고
# Out:
#              acc_cnt  acc_cnt_cmrt  dth_dnv_cnt  dth_dnv_cnt_cmrt  ftlt_rate  \
# sido_sgg_nm
# 경기도           243083        249.05         5106            222.41      23.11
# 서울특별시         211041        214.57         2269             98.82      11.69
# 대구광역시          70426         71.55         1008             43.88      15.62
# 경상북도           64697         65.50         2594            111.91      43.43
# 부산광역시          63308         64.23         1032             44.12      17.62
# 경상남도           58252         59.02         2091             91.59      39.29
# 인천광역시          47713         48.30          890             38.58      20.27
# 광주광역시          43050         43.68          611             26.18      15.42
# 충청북도           41891         42.77         1294             56.75      33.76
# 충청남도           41775         42.62         2065             90.02      54.04
# 전라남도           40865         41.53         1860             80.55      49.49
# 전라북도           39037         39.32         1622             70.50      45.63
# 대전광역시          35588         36.55          620             27.28      19.26
# 강원도            35412         35.81         1118             48.73      34.48
# 울산광역시          24640         24.88          565             24.11      24.71
# 제주도            17735         18.13          487             21.22      30.23
# 세종특별자치시         2251          2.40           72              3.38      32.21
#
#              injpsn_cnt  injpsn_cnt_cmrt  tot_acc_cnt  tot_dth_dnv_cnt  \
# sido_sgg_nm
# 경기도              374003           253.19      1080764            25304
# 서울특별시            307486           206.26      1080764            25304
# 대구광역시            105433            70.77      1080764            25304
# 경상북도              97332            64.98      1080764            25304
# 부산광역시             90313            60.44      1080764            25304
# 경상남도              83952            56.09      1080764            25304
# 인천광역시             72811            48.56      1080764            25304
# 광주광역시             70538            47.29      1080764            25304
# 충청북도              67011            45.23      1080764            25304
# 충청남도              64085            43.11      1080764            25304
# 전라남도              65537            43.98      1080764            25304
# 전라북도              61159            40.58      1080764            25304
# 대전광역시             55062            37.43      1080764            25304
# 강원도               57127            38.03      1080764            25304
# 울산광역시             36263            24.17      1080764            25304
# 제주도               25837            17.52      1080764            25304
# 세종특별자치시            3405             2.42       862075            19513
#
#              tot_injpsn_cnt
# sido_sgg_nm
# 경기도                 1637354
# 서울특별시               1637354
# 대구광역시               1637354
# 경상북도                1637354
# 부산광역시               1637354
# 경상남도                1637354
# 인천광역시               1637354
# 광주광역시               1637354
# 충청북도                1637354
# 충청남도                1637354
# 전라남도                1637354
# 전라북도                1637354
# 대전광역시               1637354
# 강원도                 1637354
# 울산광역시               1637354
# 제주도                 1637354
# 세종특별자치시             1296941

# %%
print('야간 사고가 가장 많은 지역:', df_total_야간사고.index[0], df_total_야간사고.iloc[0,0])
print('야간 사고가 가장 적은 지역:', df_total_야간사고.index[-1], df_total_야간사고.iloc[0,-1])
# Out:
# 야간 사고가 가장 많은 지역: 경기도 243083
# 야간 사고가 가장 적은 지역: 세종특별자치시 1637354

# %%
'''
2. 과속 건수와 사고 건수의 상관 관계
'''
import requests
import pandas as pd

df_total = pd.DataFrame()
url = 'http://apis.data.go.kr/B552061/lgStat/getRestLgStat'

for year in range(2010,2021):
    print(f"Year: {year}")
    
    params = {
    "ServiceKey" : 'HCnD0rtW2xL5JgkUNzOEFPuVQO9FxnqdTxFgkAkNYh2eacEW62WkpsWVn7W+UoQNKJXa1HIc8IR9t6ZkI4wzIA=='
    , 'searchYearCd': year
    , 'siDo': 1100 # 서울 전체
    , 'guGun': '' # 서울 전체 구
    , 'type': 'json'
    , 'numOfRows': 5000
    , 'pageNo': 1
    }
    
    res = requests.get(url, params = params)
#     print(res.json())
    
    data = res.json()['items']['item']
    df = pd.DataFrame(data=data)
    
    cond = df['acc_cl_nm'] == '전체사고'
    df = df[cond]
    df = df.iloc[:, :13].copy()
    
    df['std_year'] = df['std_year'].astype('int')
    df['acc_cnt'] = df['acc_cnt'].astype('int')
    df['acc_cnt_cmrt'] = df['acc_cnt_cmrt'].astype('float')
    df['dth_dnv_cnt'] = df['dth_dnv_cnt'].astype('int')
    df['dth_dnv_cnt_cmrt'] = df['dth_dnv_cnt_cmrt'].astype('float')
    df['ftlt_rate'] = df['ftlt_rate'].astype('float')
    df['injpsn_cnt'] = df['injpsn_cnt'].astype('int')
    df['injpsn_cnt_cmrt'] = df['injpsn_cnt_cmrt'].astype('float')
    df['tot_acc_cnt'] = df['tot_acc_cnt'].astype('int')
    df['tot_dth_dnv_cnt'] = df['tot_dth_dnv_cnt'].astype('int')
    df['tot_injpsn_cnt'] = df['tot_injpsn_cnt'].astype('int')
    
    df_total = df_total.append(df)
    
df_total = df_total.set_index('std_year')
df_total
# Out:
# Year: 2010
# Year: 2011
# Year: 2012
# Year: 2013
# Year: 2014
# Year: 2015
# Year: 2016
# Year: 2017
# Year: 2018
# Year: 2019
# Year: 2020
#          sido_sgg_nm acc_cl_nm  acc_cnt  acc_cnt_cmrt  dth_dnv_cnt  \
# std_year
# 2010           서울특별시      전체사고    41662         18.36          429
# 2010       서울특별시 강남구      전체사고     3551          1.59           31
# 2010       서울특별시 강동구      전체사고     1410          0.63           14
# 2010       서울특별시 강북구      전체사고     1293          0.58           16
# 2010       서울특별시 강서구      전체사고     1872          0.84           21
# ...              ...       ...      ...           ...          ...
# 2020       서울특별시 용산구      전체사고      890          0.42           12
# 2020       서울특별시 은평구      전체사고      953          0.45           14
# 2020       서울특별시 종로구      전체사고      903          0.43            5
# 2020        서울특별시 중구      전체사고      955          0.46            6
# 2020       서울특별시 중랑구      전체사고     1447          0.69            4
#
#           dth_dnv_cnt_cmrt  ftlt_rate  injpsn_cnt  injpsn_cnt_cmrt  \
# std_year
# 2010                  7.79       1.03       59718            16.94
# 2010                  0.57       0.87        5176             1.49
# 2010                  0.26       0.99        1945             0.56
# 2010                  0.29       1.24        1780             0.51
# 2010                  0.39       1.12        2594             0.75
# ...                    ...        ...         ...              ...
# 2020                  0.39       1.35        1178             0.38
# 2020                  0.45       1.47        1415             0.46
# 2020                  0.16       0.55        1224             0.40
# 2020                  0.19       0.63        1248             0.41
# 2020                  0.13       0.28        1952             0.64
#
#           tot_acc_cnt  tot_dth_dnv_cnt  tot_injpsn_cnt
# std_year
# 2010           226878             5505          352458
# 2010           226878             5505          352458
# 2010           226878             5505          352458
# 2010           226878             5505          352458
# 2010           226878             5505          352458
# ...               ...              ...             ...
# 2020           209654             3081          306194
# 2020           209654             3081          306194
# 2020           209654             3081          306194
# 2020           209654             3081          306194
# 2020           209654             3081          306194
#
# [286 rows x 12 columns]

# %%
cond = df_total['acc_cl_nm'] == '전체사고'
df_total_전체사고 = df_total.loc[cond]
df_total_전체사고
# Out:
#          sido_sgg_nm acc_cl_nm  acc_cnt  acc_cnt_cmrt  dth_dnv_cnt  \
# std_year
# 2010           서울특별시      전체사고    41662         18.36          429
# 2010       서울특별시 강남구      전체사고     3551          1.59           31
# 2010       서울특별시 강동구      전체사고     1410          0.63           14
# 2010       서울특별시 강북구      전체사고     1293          0.58           16
# 2010       서울특별시 강서구      전체사고     1872          0.84           21
# ...              ...       ...      ...           ...          ...
# 2020       서울특별시 용산구      전체사고      890          0.42           12
# 2020       서울특별시 은평구      전체사고      953          0.45           14
# 2020       서울특별시 종로구      전체사고      903          0.43            5
# 2020        서울특별시 중구      전체사고      955          0.46            6
# 2020       서울특별시 중랑구      전체사고     1447          0.69            4
#
#           dth_dnv_cnt_cmrt  ftlt_rate  injpsn_cnt  injpsn_cnt_cmrt  \
# std_year
# 2010                  7.79       1.03       59718            16.94
# 2010                  0.57       0.87        5176             1.49
# 2010                  0.26       0.99        1945             0.56
# 2010                  0.29       1.24        1780             0.51
# 2010                  0.39       1.12        2594             0.75
# ...                    ...        ...         ...              ...
# 2020                  0.39       1.35        1178             0.38
# 2020                  0.45       1.47        1415             0.46
# 2020                  0.16       0.55        1224             0.40
# 2020                  0.19       0.63        1248             0.41
# 2020                  0.13       0.28        1952             0.64
#
#           tot_acc_cnt  tot_dth_dnv_cnt  tot_injpsn_cnt
# std_year
# 2010           226878             5505          352458
# 2010           226878             5505          352458
# 2010           226878             5505          352458
# 2010           226878             5505          352458
# 2010           226878             5505          352458
# ...               ...              ...             ...
# 2020           209654             3081          306194
# 2020           209654             3081          306194
# 2020           209654             3081          306194
# 2020           209654             3081          306194
# 2020           209654             3081          306194
#
# [286 rows x 12 columns]

# %%
df_total_전체사고 = df_total_전체사고.groupby(by=['acc_cnt']).sum().sort_values(by='acc_cnt', ascending = False)
df_total_전체사고
# Out:
#          acc_cnt_cmrt  dth_dnv_cnt  dth_dnv_cnt_cmrt  ftlt_rate  injpsn_cnt  \
# acc_cnt
# 41665           17.96          376              8.14       0.90       58656
# 41662           18.36          429              7.79       1.03       59718
# 40829           18.26          424              7.86       1.04       58583
# 40792           18.25          400              8.40       0.98       57345
# 40451           18.24          435              8.32       1.08       57625
# ...               ...          ...               ...        ...         ...
# 852              0.37            4              0.12       0.47        1163
# 824              0.76           12              0.30       1.46        2289
# 810              0.39            6              0.19       0.74        1084
# 799              0.36           15              0.35       1.88        1133
# 741              0.35            7              0.23       0.94         990
#
#          injpsn_cnt_cmrt  tot_acc_cnt  tot_dth_dnv_cnt  tot_injpsn_cnt
# acc_cnt
# 41665              16.74       232035             4621          350400
# 41662              16.94       226878             5505          352458
# 40829              17.00       223656             5392          344565
# 40792              16.99       223552             4762          337497
# 40451              16.88       221711             5229          341391
# ...                  ...          ...              ...             ...
# 852                 0.34       229600             3349          341712
# 824                 0.71       433483             7966          645866
# 810                 0.35       209654             3081          306194
# 799                 0.34       220917             4292          331720
# 741                 0.32       209654             3081          306194
#
# [261 rows x 9 columns]

# %%
'''
지역별 무면허 사고와 총 사망자 수 상관관계, 비례여부
'''
import requests
import pandas as pd

df_total = pd.DataFrame()
url = 'http://apis.data.go.kr/B552061/lgStat/getRestLgStat'

for year in range(2010,2021):
    print(f"Year: {year}")
    
    params = {
    "ServiceKey" : 'HCnD0rtW2xL5JgkUNzOEFPuVQO9FxnqdTxFgkAkNYh2eacEW62WkpsWVn7W+UoQNKJXa1HIc8IR9t6ZkI4wzIA=='
    , 'searchYearCd': year
    , 'siDo': 1100 # 서울 전체
    , 'guGun': '' # 서울 전체 구
    , 'type': 'json'
    , 'numOfRows': 5000
    , 'pageNo': 1
    }
    
    res = requests.get(url, params = params)
#     print(res.json())
    
    data = res.json()['items']['item']
    df = pd.DataFrame(data=data)
    
    cond = df['acc_cl_nm'] == '무면허사고'
    df = df[cond]
    df = df.iloc[:, :13].copy()
    
    df['std_year'] = df['std_year'].astype('int')
    df['acc_cnt'] = df['acc_cnt'].astype('int')
    df['acc_cnt_cmrt'] = df['acc_cnt_cmrt'].astype('float')
    df['dth_dnv_cnt'] = df['dth_dnv_cnt'].astype('int')
    df['dth_dnv_cnt_cmrt'] = df['dth_dnv_cnt_cmrt'].astype('float')
    df['ftlt_rate'] = df['ftlt_rate'].astype('float')
    df['injpsn_cnt'] = df['injpsn_cnt'].astype('int')
    df['injpsn_cnt_cmrt'] = df['injpsn_cnt_cmrt'].astype('float')
    df['tot_acc_cnt'] = df['tot_acc_cnt'].astype('int')
    df['tot_dth_dnv_cnt'] = df['tot_dth_dnv_cnt'].astype('int')
    df['tot_injpsn_cnt'] = df['tot_injpsn_cnt'].astype('int')
    
    df_total = df_total.append(df)
    
df_total = df_total.set_index('std_year')
df2 = df[:7].copy()
df_total
# Out:
# Year: 2010
# Year: 2011
# Year: 2012
# Year: 2013
# Year: 2014
# Year: 2015
# Year: 2016
# Year: 2017
# Year: 2018
# Year: 2019
# Year: 2020
#          sido_sgg_nm acc_cl_nm  acc_cnt  acc_cnt_cmrt  dth_dnv_cnt  \
# std_year
# 2010           서울특별시     무면허사고     1004         11.31           13
# 2010       서울특별시 강남구     무면허사고       85          0.96            1
# 2010       서울특별시 강동구     무면허사고       33          0.37            0
# 2010       서울특별시 강북구     무면허사고       43          0.48            0
# 2010       서울특별시 강서구     무면허사고       41          0.46            1
# ...              ...       ...      ...           ...          ...
# 2020       서울특별시 용산구     무면허사고       15          0.28            0
# 2020       서울특별시 은평구     무면허사고       19          0.36            0
# 2020       서울특별시 종로구     무면허사고        8          0.15            0
# 2020        서울특별시 중구     무면허사고       15          0.28            0
# 2020       서울특별시 중랑구     무면허사고       24          0.45            0
#
#           dth_dnv_cnt_cmrt  ftlt_rate  injpsn_cnt  injpsn_cnt_cmrt  \
# std_year
# 2010                  3.36       1.29        1441            10.86
# 2010                  0.26       1.18         112             0.84
# 2010                  0.00       0.00          53             0.40
# 2010                  0.00       0.00          64             0.48
# 2010                  0.26       2.44          52             0.39
# ...                    ...        ...         ...              ...
# 2020                  0.00       0.00          20             0.26
# 2020                  0.00       0.00          26             0.34
# 2020                  0.00       0.00          10             0.13
# 2020                  0.00       0.00          18             0.24
# 2020                  0.00       0.00          34             0.45
#
#           tot_acc_cnt  tot_dth_dnv_cnt  tot_injpsn_cnt
# std_year
# 2010             8875              387           13272
# 2010             8875              387           13272
# 2010             8875              387           13272
# 2010             8875              387           13272
# 2010             8875              387           13272
# ...               ...              ...             ...
# 2020             5307              169            7597
# 2020             5307              169            7597
# 2020             5307              169            7597
# 2020             5307              169            7597
# 2020             5307              169            7597
#
# [286 rows x 12 columns]

# %%
cond = df_total['acc_cl_nm'] == '무면허사고'
무면허 = df_total.loc[cond]
무면허
# Out:
#          sido_sgg_nm acc_cl_nm  acc_cnt  acc_cnt_cmrt  dth_dnv_cnt  \
# std_year
# 2010           서울특별시     무면허사고     1004         11.31           13
# 2010       서울특별시 강남구     무면허사고       85          0.96            1
# 2010       서울특별시 강동구     무면허사고       33          0.37            0
# 2010       서울특별시 강북구     무면허사고       43          0.48            0
# 2010       서울특별시 강서구     무면허사고       41          0.46            1
# ...              ...       ...      ...           ...          ...
# 2020       서울특별시 용산구     무면허사고       15          0.28            0
# 2020       서울특별시 은평구     무면허사고       19          0.36            0
# 2020       서울특별시 종로구     무면허사고        8          0.15            0
# 2020        서울특별시 중구     무면허사고       15          0.28            0
# 2020       서울특별시 중랑구     무면허사고       24          0.45            0
#
#           dth_dnv_cnt_cmrt  ftlt_rate  injpsn_cnt  injpsn_cnt_cmrt  \
# std_year
# 2010                  3.36       1.29        1441            10.86
# 2010                  0.26       1.18         112             0.84
# 2010                  0.00       0.00          53             0.40
# 2010                  0.00       0.00          64             0.48
# 2010                  0.26       2.44          52             0.39
# ...                    ...        ...         ...              ...
# 2020                  0.00       0.00          20             0.26
# 2020                  0.00       0.00          26             0.34
# 2020                  0.00       0.00          10             0.13
# 2020                  0.00       0.00          18             0.24
# 2020                  0.00       0.00          34             0.45
#
#           tot_acc_cnt  tot_dth_dnv_cnt  tot_injpsn_cnt
# std_year
# 2010             8875              387           13272
# 2010             8875              387           13272
# 2010             8875              387           13272
# 2010             8875              387           13272
# 2010             8875              387           13272
# ...               ...              ...             ...
# 2020             5307              169            7597
# 2020             5307              169            7597
# 2020             5307              169            7597
# 2020             5307              169            7597
# 2020             5307              169            7597
#
# [286 rows x 12 columns]

# %%
import matplotlib.pyplot as plt

plt.pie(df_total['acc_cnt'], labels = df_total['dth_dnv_cnt'], autopct='%.1f%%' )

plt.show()

# %%
value = 무면허.groupby(by=['sido_sgg_nm']).sum().sort_values(by='dth_dnv_cnt', ascending = False)
dead = value.set_index('dth_dnv_cnt')

# %%
import matplotlib.pyplot as plt

plt.pie(df_total['dth_dnv_cnt'], labels = df_total['sido_sgg_nm'], autopct='%.1f%%' )

plt.show()

# %%
df2 = df[:10].copy()
df2
# Out:
#      std_year sido_sgg_nm acc_cl_nm  acc_cnt  acc_cnt_cmrt  dth_dnv_cnt  \
# 12       2020       서울특별시     무면허사고      571         10.76            5
# 25       2020   서울특별시 강남구     무면허사고       71          1.34            2
# 38       2020   서울특별시 강동구     무면허사고       23          0.43            1
# 51       2020   서울특별시 강북구     무면허사고       10          0.19            0
# 64       2020   서울특별시 강서구     무면허사고       21          0.40            0
# 77       2020   서울특별시 관악구     무면허사고       31          0.58            0
# 90       2020   서울특별시 광진구     무면허사고       21          0.40            0
# 103      2020   서울특별시 구로구     무면허사고       37          0.70            0
# 116      2020   서울특별시 금천구     무면허사고       15          0.28            0
# 129      2020   서울특별시 노원구     무면허사고       23          0.43            0
#
#      dth_dnv_cnt_cmrt  ftlt_rate  injpsn_cnt  injpsn_cnt_cmrt  tot_acc_cnt  \
# 12               2.96       0.88         774            10.19         5307
# 25               1.18       2.82          80             1.05         5307
# 38               0.59       4.35          33             0.43         5307
# 51               0.00       0.00          18             0.24         5307
# 64               0.00       0.00          34             0.45         5307
# 77               0.00       0.00          41             0.54         5307
# 90               0.00       0.00          23             0.30         5307
# 103              0.00       0.00          45             0.59         5307
# 116              0.00       0.00          21             0.28         5307
# 129              0.00       0.00          34             0.45         5307
#
#      tot_dth_dnv_cnt  tot_injpsn_cnt
# 12               169            7597
# 25               169            7597
# 38               169            7597
# 51               169            7597
# 64               169            7597
# 77               169            7597
# 90               169            7597
# 103              169            7597
# 116              169            7597
# 129              169            7597

# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/NGULIM.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)
# https://medium.com/@kvnamipara/a-better-visualisation-of-pie-charts-by-matplotlib-935b7667d77f
colors = [ '#ff9999', '#66b3ff', '#99ff99','#bcbd22', '#ffcc99','#1f77b4','#ff7f0e','#2ca02c','#7f7f7f','#17becf'] 
fig1, ax1 = plt.subplots ()

ax1.pie (df2['dth_dnv_cnt'], colors = colors , labels = df2['sido_sgg_nm'], autopct = '% 1.1f %%', startangle=360)

# plt.pie(df2['dth_dnv_cnt'], labels = df2['sido_sgg_nm'], autopct='%.1f%%' )

centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

ax1.axis('equal')
plt.title('서울 무면허사고에 따른 사망자 분포')
plt.tight_layout()
plt.show()

# %%
from xml.etree import ElementTree
xml_string = '''
<data>
    <student>
        <name>갑</name>
        <age>50</age>
        <score korean="90" english="80"/>
    </student>
    <student>
        <name>을</name>
        <age>45</age>
        <score korean="95" english="60"/>
    </student>
</data>
'''
# root = ElementTree.fromstring(xml_string)
# print(type(root)) # 문자열로부터 변환

tree = ElementTree.parse('data.xml') #xml파일로부터 변환
root = tree.getroot()

student = root.find('student')
print(type(student))

print(student.findtext('name'))
print(student.findtext('age'))
print(student.find('score').attrib)
print(student.find('score').attrib.get('korean'))
print(student.find('score').attrib['english'])

print('-'*20)

students = root.findall('student')
for student in students:
    print(student.findtext('name'))
    print(student.findtext('age'))
    print(student.find('score').attrib)
    print()
    
print('-'*20)
names = [x.findtext('name') for x in students]
ages = [x.findtext('age') for x in students]
print(names)
print(ages)
# Out:
# <class 'xml.etree.ElementTree.Element'>
# 갑
# 50
# {'korean': '90', 'english': '80'}
# 90
# 80
# --------------------
# 갑
# 50
# {'korean': '90', 'english': '80'}
#
# 을
# 45
# {'korean': '95', 'english': '60'}
#
# --------------------
# ['갑', '을']
# ['50', '45']

# %%
# !pip install xmltodict
# Out:
# Requirement already satisfied: xmltodict in c:\users\cjh\anaconda3\lib\site-packages (0.12.0)

# %%
# XML 을 JSON 형태로 변환
import xmltodict
import json

xml_string = '''
<data>
    <student>
        <name>갑</name>
        <age>50</age>
        <score korean="90" english="80"/>
    </student>
    <student>
        <name>을</name>
        <age>45</age>
        <score korean="95" english="60"/>
    </student>
</data>
'''
# Ordered Dictionary 로 변환
dict_type = xmltodict.parse(xml_string)
print(dict_type)
print()

# Dictionary 로 변환
json_type = json.dumps(dict_type)
dict2_type = json.loads(json_type)
print(dict2_type)
# Out:
# OrderedDict([('data', OrderedDict([('student', [OrderedDict([('name', '갑'), ('age', '50'), ('score', OrderedDict([('@korean', '90'), ('@english', '80')]))]), OrderedDict([('name', '을'), ('age', '45'), ('score', OrderedDict([('@korean', '95'), ('@english', '60')]))])])]))])
#
# {'data': {'student': [{'name': '갑', 'age': '50', 'score': {'@korean': '90', '@english': '80'}}, {'name': '을', 'age': '45', 'score': {'@korean': '95', '@english': '60'}}]}}

# %% [markdown]
# ## Requsts - Reponse

# %%
import requests

url = 'http://apis.data.go.kr/B552061/lgStat/getRestLgStat'

params = {
    "ServiceKey" : 'HCnD0rtW2xL5JgkUNzOEFPuVQO9FxnqdTxFgkAkNYh2eacEW62WkpsWVn7W+UoQNKJXa1HIc8IR9t6ZkI4wzIA=='
    , 'searchYearCd': 2019
    , 'siDo': 1100
    , 'guGun': ''
    , 'type': 'xml'
    , 'numOfRows': 13
    , 'pageNo': 1
}

res = requests.get(url, params = params)
print(res.status_code)
print(res.text)
# Out:
# 200
# <response>
#     <header>
#         <resultCode>00</resultCode>
#         <resultMsg>NORMAL_CODE</resultMsg>
#     </header>
#     <body>
#         <items>
#             <item>
#                 <std_year>2019</std_year>
#                 <acc_cl_nm>전체사고</acc_cl_nm>
#                 <sido_sgg_nm>서울특별시</sido_sgg_nm>
#                 <acc_cnt>39258</acc_cnt>
#                 <acc_cnt_cmrt>17.10</acc_cnt_cmrt>
#                 <dth_dnv_cnt>250</dth_dnv_cnt>
#                 <dth_dnv_cnt_cmrt>7.46</dth_dnv_cnt_cmrt>
#                 <ftlt_rate>0.64</ftlt_rate>
#                 <injpsn_cnt>53904</injpsn_cnt>
#                 <injpsn_cnt_cmrt>15.77</injpsn_cnt_cmrt>
#                 <tot_acc_cnt>229600</tot_acc_cnt>
#                 <tot_dth_dnv_cnt>3349</tot_dth_dnv_cnt>
#                 <tot_injpsn_cnt>341712</tot_injpsn_cnt>
#                 <pop_100k>406.31</pop_100k>
#                 <car_10k>108.57</car_10k>
#                 <cnt_027_01>102</cnt_027_01>
#                 <cnt_027_02>1074</cnt_027_02>
#                 <cnt_027_03>4898</cnt_027_03>
#                 <cnt_027_04>5259</cnt_027_04>
#                 <cnt_027_05>21842</cnt_027_05>
#                 <cnt_027_06>1325</cnt_027_06>
#                 <cnt_027_07>1515</cnt_027_07>
#                 <cnt_027_99>3243</cnt_027_99>
#                 <cnt_014_01>9896</cnt_014_01>
#                 <cnt_014_02>28150</cnt_014_02>
#                 <cnt_014_03>1212</cnt_014_03>
#                 <cnt_014_04>0</cnt_014_04>
#             </item>
#             <item>
#                 <std_year>2019</std_year>
#                 <acc_cl_nm>어린이사고</acc_cl_nm>
#                 <sido_sgg_nm>서울특별시</sido_sgg_nm>
#                 <acc_cnt>1475</acc_cnt>
#                 <acc_cnt_cmrt>13.34</acc_cnt_cmrt>
#                 <dth_dnv_cnt>3</dth_dnv_cnt>
#                 <dth_dnv_cnt_cmrt>10.71</dth_dnv_cnt_cmrt>
#                 <ftlt_rate>0.20</ftlt_rate>
#                 <injpsn_cnt>1770</injpsn_cnt>
#                 <injpsn_cnt_cmrt>12.54</injpsn_cnt_cmrt>
#                 <tot_acc_cnt>11054</tot_acc_cnt>
#                 <tot_dth_dnv_cnt>28</tot_dth_dnv_cnt>
#                 <tot_injpsn_cnt>14115</tot_injpsn_cnt>
#             </item>
#             <item>
#                 <std_year>2019</std_year>
#                 <acc_cl_nm>고령자사고</acc_cl_nm>
#                 <sido_sgg_nm>서울특별시</sido_sgg_nm>
#                 <acc_cnt>5912</acc_cnt>
#                 <acc_cnt_cmrt>14.55</acc_cnt_cmrt>
#                 <dth_dnv_cnt>103</dth_dnv_cnt>
#                 <dth_dnv_cnt_cmrt>6.76</dth_dnv_cnt_cmrt>
#                 <ftlt_rate>1.74</ftlt_rate>
#                 <injpsn_cnt>6200</injpsn_cnt>
#                 <injpsn_cnt_cmrt>13.97</injpsn_cnt_cmrt>
#                 <tot_acc_cnt>40645</tot_acc_cnt>
#                 <tot_dth_dnv_cnt>1523</tot_dth_dnv_cnt>
#                 <tot_injpsn_cnt>44390</tot_injpsn_cnt>
#             </item>
#             <item>
#                 <std_year>2019</std_year>
#                 <acc_cl_nm>보행자사고</acc_cl_nm>
#                 <sido_sgg_nm>서울특별시</sido_sgg_nm>
#                 <acc_cnt>9989</acc_cnt>
#                 <acc_cnt_cmrt>21.40</acc_cnt_cmrt>
#                 <dth_dnv_cnt>144</dth_dnv_cnt>
#                 <dth_dnv_cnt_cmrt>11.06</dth_dnv_cnt_cmrt>
#                 <ftlt_rate>1.44</ftlt_rate>
#                 <injpsn_cnt>10197</injpsn_cnt>
#                 <injpsn_cnt_cmrt>21.60</injpsn_cnt_cmrt>
#                 <tot_acc_cnt>46682</tot_acc_cnt>
#                 <tot_dth_dnv_cnt>1302</tot_dth_dnv_cnt>
#                 <tot_injpsn_cnt>47200</tot_injpsn_cnt>
#             </item>
#             <item>
#                 <std_year>2019</std_year>
#                 <acc_cl_nm>자전거사고</acc_cl_nm>
#                 <sido_sgg_nm>서울특별시</sido_sgg_nm>
#                 <acc_cnt>1766</acc_cnt>
#                 <acc_cnt_cmrt>31.35</acc_cnt_cmrt>
#                 <dth_dnv_cnt>11</dth_dnv_cnt>
#                 <dth_dnv_cnt_cmrt>13.92</dth_dnv_cnt_cmrt>
#                 <ftlt_rate>0.62</ftlt_rate>
#                 <injpsn_cnt>1950</injpsn_cnt>
#                 <injpsn_cnt_cmrt>32.39</injpsn_cnt_cmrt>
#                 <tot_acc_cnt>5633</tot_acc_cnt>
#                 <tot_dth_dnv_cnt>79</tot_dth_dnv_cnt>
#                 <tot_injpsn_cnt>6020</tot_injpsn_cnt>
#             </item>
#             <item>
#                 <std_year>2019</std_year>
#                 <acc_cl_nm>야간사고</acc_cl_nm>
#                 <sido_sgg_nm>서울특별시</sido_sgg_nm>
#                 <acc_cnt>17021</acc_cnt>
#                 <acc_cnt_cmrt>18.69</acc_cnt_cmrt>
#                 <dth_dnv_cnt>147</dth_dnv_cnt>
#                 <dth_dnv_cnt_cmrt>9.19</dth_dnv_cnt_cmrt>
#                 <ftlt_rate>0.86</ftlt_rate>
#                 <injpsn_cnt>23820</injpsn_cnt>
#                 <injpsn_cnt_cmrt>17.69</injpsn_cnt_cmrt>
#                 <tot_acc_cnt>91067</tot_acc_cnt>
#                 <tot_dth_dnv_cnt>1599</tot_dth_dnv_cnt>
#                 <tot_injpsn_cnt>134686</tot_injpsn_cnt>
#             </item>
#             <item>
#                 <std_year>2019</std_year>
#                 <acc_cl_nm>어린이보행사고</acc_cl_nm>
#                 <sido_sgg_nm>서울특별시</sido_sgg_nm>
#                 <acc_cnt>634</acc_cnt>
#                 <acc_cnt_cmrt>16.44</acc_cnt_cmrt>
#                 <dth_dnv_cnt>3</dth_dnv_cnt>
#                 <dth_dnv_cnt_cmrt>15.00</dth_dnv_cnt_cmrt>
#                 <ftlt_rate>0.47</ftlt_rate>
#                 <injpsn_cnt>641</injpsn_cnt>
#                 <injpsn_cnt_cmrt>16.26</injpsn_cnt_cmrt>
#                 <tot_acc_cnt>3856</tot_acc_cnt>
#                 <tot_dth_dnv_cnt>20</tot_dth_dnv_cnt>
#                 <tot_injpsn_cnt>3942</tot_injpsn_cnt>
#             </item>
#             <item>
#                 <std_year>2019</std_year>
#                 <acc_cl_nm>스쿨존내어린이사고</acc_cl_nm>
#                 <sido_sgg_nm>서울특별시</sido_sgg_nm>
#                 <acc_cnt>114</acc_cnt>
#                 <acc_cnt_cmrt>20.11</acc_cnt_cmrt>
#                 <dth_dnv_cnt>2</dth_dnv_cnt>
#                 <dth_dnv_cnt_cmrt>33.33</dth_dnv_cnt_cmrt>
#                 <ftlt_rate>1.75</ftlt_rate>
#                 <injpsn_cnt>115</injpsn_cnt>
#                 <injpsn_cnt_cmrt>19.52</injpsn_cnt_cmrt>
#                 <tot_acc_cnt>567</tot_acc_cnt>
#                 <tot_dth_dnv_cnt>6</tot_dth_dnv_cnt>
#                 <tot_injpsn_cnt>589</tot_injpsn_cnt>
#             </item>
#             <item>
#                 <std_year>2019</std_year>
#                 <acc_cl_nm>고령운전자사고</acc_cl_nm>
#                 <sido_sgg_nm>서울특별시</sido_sgg_nm>
#                 <acc_cnt>5886</acc_cnt>
#                 <acc_cnt_cmrt>17.71</acc_cnt_cmrt>
#                 <dth_dnv_cnt>49</dth_dnv_cnt>
#                 <dth_dnv_cnt_cmrt>6.37</dth_dnv_cnt_cmrt>
#                 <ftlt_rate>0.83</ftlt_rate>
#                 <injpsn_cnt>7881</injpsn_cnt>
#                 <injpsn_cnt_cmrt>16.34</injpsn_cnt_cmrt>
#                 <tot_acc_cnt>33239</tot_acc_cnt>
#                 <tot_dth_dnv_cnt>769</tot_dth_dnv_cnt>
#                 <tot_injpsn_cnt>48223</tot_injpsn_cnt>
#             </item>
#             <item>
#                 <std_year>2019</std_year>
#                 <acc_cl_nm>고령보행자사고</acc_cl_nm>
#                 <sido_sgg_nm>서울특별시</sido_sgg_nm>
#                 <acc_cnt>2268</acc_cnt>
#                 <acc_cnt_cmrt>18.52</acc_cnt_cmrt>
#                 <dth_dnv_cnt>72</dth_dnv_cnt>
#                 <dth_dnv_cnt_cmrt>9.69</dth_dnv_cnt_cmrt>
#                 <ftlt_rate>3.17</ftlt_rate>
#                 <injpsn_cnt>2231</injpsn_cnt>
#                 <injpsn_cnt_cmrt>19.15</injpsn_cnt_cmrt>
#                 <tot_acc_cnt>12249</tot_acc_cnt>
#                 <tot_dth_dnv_cnt>743</tot_dth_dnv_cnt>
#                 <tot_injpsn_cnt>11653</tot_injpsn_cnt>
#             </item>
#             <item>
#                 <std_year>2019</std_year>
#                 <acc_cl_nm>개인이동수단(PM)사고</acc_cl_nm>
#                 <sido_sgg_nm>서울특별시</sido_sgg_nm>
#                 <acc_cnt>134</acc_cnt>
#                 <acc_cnt_cmrt>29.98</acc_cnt_cmrt>
#                 <dth_dnv_cnt>1</dth_dnv_cnt>
#                 <dth_dnv_cnt_cmrt>12.50</dth_dnv_cnt_cmrt>
#                 <ftlt_rate>0.75</ftlt_rate>
#                 <injpsn_cnt>139</injpsn_cnt>
#                 <injpsn_cnt_cmrt>29.39</injpsn_cnt_cmrt>
#                 <tot_acc_cnt>447</tot_acc_cnt>
#                 <tot_dth_dnv_cnt>8</tot_dth_dnv_cnt>
#                 <tot_injpsn_cnt>473</tot_injpsn_cnt>
#             </item>
#             <item>
#                 <std_year>2019</std_year>
#                 <acc_cl_nm>뺑소니사고</acc_cl_nm>
#                 <sido_sgg_nm>서울특별시</sido_sgg_nm>
#                 <acc_cnt>721</acc_cnt>
#                 <acc_cnt_cmrt>10.11</acc_cnt_cmrt>
#                 <dth_dnv_cnt>5</dth_dnv_cnt>
#                 <dth_dnv_cnt_cmrt>5.56</dth_dnv_cnt_cmrt>
#                 <ftlt_rate>0.69</ftlt_rate>
#                 <injpsn_cnt>1094</injpsn_cnt>
#                 <injpsn_cnt_cmrt>10.64</injpsn_cnt_cmrt>
#                 <tot_acc_cnt>7129</tot_acc_cnt>
#                 <tot_dth_dnv_cnt>90</tot_dth_dnv_cnt>
#                 <tot_injpsn_cnt>10285</tot_injpsn_cnt>
#             </item>
#             <item>
#                 <std_year>2019</std_year>
#                 <acc_cl_nm>무면허사고</acc_cl_nm>
#                 <sido_sgg_nm>서울특별시</sido_sgg_nm>
#                 <acc_cnt>557</acc_cnt>
#                 <acc_cnt_cmrt>10.76</acc_cnt_cmrt>
#                 <dth_dnv_cnt>3</dth_dnv_cnt>
#                 <dth_dnv_cnt_cmrt>1.84</dth_dnv_cnt_cmrt>
#                 <ftlt_rate>0.54</ftlt_rate>
#                 <injpsn_cnt>796</injpsn_cnt>
#                 <injpsn_cnt_cmrt>10.69</injpsn_cnt_cmrt>
#                 <tot_acc_cnt>5177</tot_acc_cnt>
#                 <tot_dth_dnv_cnt>163</tot_dth_dnv_cnt>
#                 <tot_injpsn_cnt>7445</tot_injpsn_cnt>
#             </item>
#         </items>
#         <totalCount>335</totalCount>
#         <numOfRows>13</numOfRows>
#         <pageNo>1</pageNo>
#     </body>
# </response>

# %% [markdown]
# ## 데이터 전처리(가공)
# - xml.etree.ElementTree 사용

# %%
import pandas as pd
import xml.etree.ElementTree as et

root = et.fromstring(res.text)
columns = []
items = root.find('body').find('items').findall('item')
for item in items[0][:13]:
    print(item.tag)
    columns.append(item.tag)
    
print()
rows = []

for item in items:
    std_year = item.findtext('std_year')
    acc_cl_nm = item.findtext('acc_cl_nm')
    sido_sgg_nm = item.findtext('sido_sgg_nm')
    acc_cnt = item.findtext('acc_cnt')
#     print(std_year, acc_cl_nm, sido_sgg_nm,acc_cnt)
    
    rows.append([std_year, acc_cl_nm, sido_sgg_nm, acc_cnt])
    
print(rows)

df = pd.DataFrame(data=data, columns=columns)
df
# Out:
# std_year
# acc_cl_nm
# sido_sgg_nm
# acc_cnt
# acc_cnt_cmrt
# dth_dnv_cnt
# dth_dnv_cnt_cmrt
# ftlt_rate
# injpsn_cnt
# injpsn_cnt_cmrt
# tot_acc_cnt
# tot_dth_dnv_cnt
# tot_injpsn_cnt
#
# [['2019', '전체사고', '서울특별시', '39258'], ['2019', '어린이사고', '서울특별시', '1475'], ['2019', '고령자사고', '서울특별시', '5912'], ['2019', '보행자사고', '서울특별시', '9989'], ['2019', '자전거사고', '서울특별시', '1766'], ['2019', '야간사고', '서울특별시', '17021'], ['2019', '어린이보행사고', '서울특별시', '634'], ['2019', '스쿨존내어린이사고', '서울특별시', '114'], ['2019', '고령운전자사고', '서울특별시', '5886'], ['2019', '고령보행자사고', '서울특별시', '2268'], ['2019', '개인이동수단(PM)사고', '서울특별시', '134'], ['2019', '뺑소니사고', '서울특별시', '721'], ['2019', '무면허사고', '서울특별시', '557']]
#     std_year     acc_cl_nm sido_sgg_nm acc_cnt acc_cnt_cmrt dth_dnv_cnt  \
# 0       2020          전체사고       서울특별시   35227        16.80         219
# 1       2020         어린이사고       서울특별시     928        11.05           2
# 2       2020         고령자사고       서울특별시    5056        14.32          86
# 3       2020         보행자사고       서울특별시    7705        21.05         115
# 4       2020         자전거사고       서울특별시    3015        23.43          23
# ..       ...           ...         ...     ...          ...         ...
# 333     2020       고령운전자사고   서울특별시 중랑구     219         0.70           2
# 334     2020       고령보행자사고   서울특별시 중랑구      99         1.02           3
# 335     2020  개인이동수단(PM)사고   서울특별시 중랑구       5         0.56           0
# 336     2020         뺑소니사고   서울특별시 중랑구      26         0.35           0
# 337     2020         무면허사고   서울특별시 중랑구      24         0.45           0
#
#     dth_dnv_cnt_cmrt ftlt_rate injpsn_cnt injpsn_cnt_cmrt tot_acc_cnt  \
# 0               7.11      0.62      47513           15.52      209654
# 1               8.33      0.22       1078           10.27        8400
# 2               6.41      1.70       5279           13.84       35312
# 3              10.52      1.49       7841           21.23       36601
# 4              11.68      0.76       3261           24.31       12866
# ..               ...       ...        ...             ...         ...
# 333             0.28      0.91        277            0.63       31072
# 334             0.48      3.03         97            1.05        9739
# 335             0.00      0.00          5            0.51         897
# 336             0.00      0.00         40            0.38        7418
# 337             0.00      0.00         34            0.45        5307
#
#     tot_dth_dnv_cnt tot_injpsn_cnt
# 0              3081         306194
# 1                24          10500
# 2              1342          38147
# 3              1093          36939
# 4               197          13414
# ..              ...            ...
# 333             720          44269
# 334             628           9233
# 335              10            985
# 336              97          10419
# 337             169           7597
#
# [338 rows x 13 columns]

# %%
import pandas as pd
import xmltodict
import json
dict_type = xmltodict.parse(res.text)

json_type = json.dumps(dict_type)
dict2_type = json.loads(json_type)
print(dict2_type)

data = dict2_type['response']['body']['items']['item']

df = pd.DataFrame(data= data)
df
# Out:
# {'response': {'header': {'resultCode': '00', 'resultMsg': 'NORMAL_CODE'}, 'body': {'items': {'item': [{'std_year': '2019', 'acc_cl_nm': '전체사고', 'sido_sgg_nm': '서울특별시', 'acc_cnt': '39258', 'acc_cnt_cmrt': '17.10', 'dth_dnv_cnt': '250', 'dth_dnv_cnt_cmrt': '7.46', 'ftlt_rate': '0.64', 'injpsn_cnt': '53904', 'injpsn_cnt_cmrt': '15.77', 'tot_acc_cnt': '229600', 'tot_dth_dnv_cnt': '3349', 'tot_injpsn_cnt': '341712', 'pop_100k': '406.31', 'car_10k': '108.57', 'cnt_027_01': '102', 'cnt_027_02': '1074', 'cnt_027_03': '4898', 'cnt_027_04': '5259', 'cnt_027_05': '21842', 'cnt_027_06': '1325', 'cnt_027_07': '1515', 'cnt_027_99': '3243', 'cnt_014_01': '9896', 'cnt_014_02': '28150', 'cnt_014_03': '1212', 'cnt_014_04': '0'}, {'std_year': '2019', 'acc_cl_nm': '어린이사고', 'sido_sgg_nm': '서울특별시', 'acc_cnt': '1475', 'acc_cnt_cmrt': '13.34', 'dth_dnv_cnt': '3', 'dth_dnv_cnt_cmrt': '10.71', 'ftlt_rate': '0.20', 'injpsn_cnt': '1770', 'injpsn_cnt_cmrt': '12.54', 'tot_acc_cnt': '11054', 'tot_dth_dnv_cnt': '28', 'tot_injpsn_cnt': '14115'}, {'std_year': '2019', 'acc_cl_nm': '고령자사고', 'sido_sgg_nm': '서울특별시', 'acc_cnt': '5912', 'acc_cnt_cmrt': '14.55', 'dth_dnv_cnt': '103', 'dth_dnv_cnt_cmrt': '6.76', 'ftlt_rate': '1.74', 'injpsn_cnt': '6200', 'injpsn_cnt_cmrt': '13.97', 'tot_acc_cnt': '40645', 'tot_dth_dnv_cnt': '1523', 'tot_injpsn_cnt': '44390'}, {'std_year': '2019', 'acc_cl_nm': '보행자사고', 'sido_sgg_nm': '서울특별시', 'acc_cnt': '9989', 'acc_cnt_cmrt': '21.40', 'dth_dnv_cnt': '144', 'dth_dnv_cnt_cmrt': '11.06', 'ftlt_rate': '1.44', 'injpsn_cnt': '10197', 'injpsn_cnt_cmrt': '21.60', 'tot_acc_cnt': '46682', 'tot_dth_dnv_cnt': '1302', 'tot_injpsn_cnt': '47200'}, {'std_year': '2019', 'acc_cl_nm': '자전거사고', 'sido_sgg_nm': '서울특별시', 'acc_cnt': '1766', 'acc_cnt_cmrt': '31.35', 'dth_dnv_cnt': '11', 'dth_dnv_cnt_cmrt': '13.92', 'ftlt_rate': '0.62', 'injpsn_cnt': '1950', 'injpsn_cnt_cmrt': '32.39', 'tot_acc_cnt': '5633', 'tot_dth_dnv_cnt': '79', 'tot_injpsn_cnt': '6020'}, {'std_year': '2019', 'acc_cl_nm': '야간사고', 'sido_sgg_nm': '서울특별시', 'acc_cnt': '17021', 'acc_cnt_cmrt': '18.69', 'dth_dnv_cnt': '147', 'dth_dnv_cnt_cmrt': '9.19', 'ftlt_rate': '0.86', 'injpsn_cnt': '23820', 'injpsn_cnt_cmrt': '17.69', 'tot_acc_cnt': '91067', 'tot_dth_dnv_cnt': '1599', 'tot_injpsn_cnt': '134686'}, {'std_year': '2019', 'acc_cl_nm': '어린이보행사고', 'sido_sgg_nm': '서울특별시', 'acc_cnt': '634', 'acc_cnt_cmrt': '16.44', 'dth_dnv_cnt': '3', 'dth_dnv_cnt_cmrt': '15.00', 'ftlt_rate': '0.47', 'injpsn_cnt': '641', 'injpsn_cnt_cmrt': '16.26', 'tot_acc_cnt': '3856', 'tot_dth_dnv_cnt': '20', 'tot_injpsn_cnt': '3942'}, {'std_year': '2019', 'acc_cl_nm': '스쿨존내어린이사고', 'sido_sgg_nm': '서울특별시', 'acc_cnt': '114', 'acc_cnt_cmrt': '20.11', 'dth_dnv_cnt': '2', 'dth_dnv_cnt_cmrt': '33.33', 'ftlt_rate': '1.75', 'injpsn_cnt': '115', 'injpsn_cnt_cmrt': '19.52', 'tot_acc_cnt': '567', 'tot_dth_dnv_cnt': '6', 'tot_injpsn_cnt': '589'}, {'std_year': '2019', 'acc_cl_nm': '고령운전자사고', 'sido_sgg_nm': '서울특별시', 'acc_cnt': '5886', 'acc_cnt_cmrt': '17.71', 'dth_dnv_cnt': '49', 'dth_dnv_cnt_cmrt': '6.37', 'ftlt_rate': '0.83', 'injpsn_cnt': '7881', 'injpsn_cnt_cmrt': '16.34', 'tot_acc_cnt': '33239', 'tot_dth_dnv_cnt': '769', 'tot_injpsn_cnt': '48223'}, {'std_year': '2019', 'acc_cl_nm': '고령보행자사고', 'sido_sgg_nm': '서울특별시', 'acc_cnt': '2268', 'acc_cnt_cmrt': '18.52', 'dth_dnv_cnt': '72', 'dth_dnv_cnt_cmrt': '9.69', 'ftlt_rate': '3.17', 'injpsn_cnt': '2231', 'injpsn_cnt_cmrt': '19.15', 'tot_acc_cnt': '12249', 'tot_dth_dnv_cnt': '743', 'tot_injpsn_cnt': '11653'}, {'std_year': '2019', 'acc_cl_nm': '개인이동수단(PM)사고', 'sido_sgg_nm': '서울특별시', 'acc_cnt': '134', 'acc_cnt_cmrt': '29.98', 'dth_dnv_cnt': '1', 'dth_dnv_cnt_cmrt': '12.50', 'ftlt_rate': '0.75', 'injpsn_cnt': '139', 'injpsn_cnt_cmrt': '29.39', 'tot_acc_cnt': '447', 'tot_dth_dnv_cnt': '8', 'tot_injpsn_cnt': '473'}, {'std_year': '2019', 'acc_cl_nm': '뺑소니사고', 'sido_sgg_nm': '서울특별시', 'acc_cnt': '721', 'acc_cnt_cmrt': '10.11', 'dth_dnv_cnt': '5', 'dth_dnv_cnt_cmrt': '5.56', 'ftlt_rate': '0.69', 'injpsn ...
#    std_year     acc_cl_nm sido_sgg_nm acc_cnt acc_cnt_cmrt dth_dnv_cnt  \
# 0      2019          전체사고       서울특별시   39258        17.10         250
# 1      2019         어린이사고       서울특별시    1475        13.34           3
# 2      2019         고령자사고       서울특별시    5912        14.55         103
# 3      2019         보행자사고       서울특별시    9989        21.40         144
# 4      2019         자전거사고       서울특별시    1766        31.35          11
# 5      2019          야간사고       서울특별시   17021        18.69         147
# 6      2019       어린이보행사고       서울특별시     634        16.44           3
# 7      2019     스쿨존내어린이사고       서울특별시     114        20.11           2
# 8      2019       고령운전자사고       서울특별시    5886        17.71          49
# 9      2019       고령보행자사고       서울특별시    2268        18.52          72
# 10     2019  개인이동수단(PM)사고       서울특별시     134        29.98           1
# 11     2019         뺑소니사고       서울특별시     721        10.11           5
# 12     2019         무면허사고       서울특별시     557        10.76           3
#
#    dth_dnv_cnt_cmrt ftlt_rate injpsn_cnt injpsn_cnt_cmrt  ... cnt_027_03  \
# 0              7.46      0.64      53904           15.77  ...       4898
# 1             10.71      0.20       1770           12.54  ...        NaN
# 2              6.76      1.74       6200           13.97  ...        NaN
# 3             11.06      1.44      10197           21.60  ...        NaN
# 4             13.92      0.62       1950           32.39  ...        NaN
# 5              9.19      0.86      23820           17.69  ...        NaN
# 6             15.00      0.47        641           16.26  ...        NaN
# 7             33.33      1.75        115           19.52  ...        NaN
# 8              6.37      0.83       7881           16.34  ...        NaN
# 9              9.69      3.17       2231           19.15  ...        NaN
# 10            12.50      0.75        139           29.39  ...        NaN
# 11             5.56      0.69       1094           10.64  ...        NaN
# 12             1.84      0.54        796           10.69  ...        NaN
#
#    cnt_027_04 cnt_027_05 cnt_027_06 cnt_027_07 cnt_027_99 cnt_014_01  \
# 0        5259      21842       1325       1515       3243       9896
# 1         NaN        NaN        NaN        NaN        NaN        NaN
# 2         NaN        NaN        NaN        NaN        NaN        NaN
# 3         NaN        NaN        NaN        NaN        NaN        NaN
# 4         NaN        NaN        NaN        NaN        NaN        NaN
# 5         NaN        NaN        NaN        NaN        NaN        NaN
# 6         NaN        NaN        NaN        NaN        NaN        NaN
# 7         NaN        NaN        NaN        NaN        NaN        NaN
# 8         NaN        NaN        NaN        NaN        NaN        NaN
# 9         NaN        NaN        NaN        NaN        NaN        NaN
# 10        NaN        NaN        NaN        NaN        NaN        NaN
# 11        NaN        NaN        NaN        NaN        NaN        NaN
# 12        NaN        NaN        NaN        NaN        NaN        NaN
#
#    cnt_014_02 cnt_014_03 cnt_014_04
# 0       28150       1212          0
# 1         NaN        NaN        NaN
# 2         NaN        NaN        NaN
# 3         NaN        NaN        NaN
# 4         NaN        NaN        NaN
# 5         NaN        NaN        NaN
# 6         NaN        NaN        NaN
# 7         NaN        NaN        NaN
# 8         NaN        NaN        NaN
# 9         NaN        NaN        NaN
# 10        NaN        NaN        NaN
# 11        NaN        NaN        NaN
# 12        NaN        NaN        NaN
#
# [13 rows x 27 columns]
